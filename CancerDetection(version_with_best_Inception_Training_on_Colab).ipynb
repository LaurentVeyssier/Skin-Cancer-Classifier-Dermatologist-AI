# %% [markdown]
# ### Mount Google Drive

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %% [markdown]
# ### Select folder with notebook. A data folder to contain the samples should be visible

# %%
### for go up directory
# %cd ..
### to go to directory
# %cd ./gdrive/My Drive/Colab Notebooks/Dermatologist_ai
# %ls
# Out:
# /
# /gdrive/My Drive/Colab Notebooks/Dermatologist_ai
# 'CancerDetection (2).ipynb'
#  Cancer_detection_withTF.ipynb
#  data/
#  fine_Resnet50_model.weights.best.hdf5
#  get_results.py
#  ground_truth.csv
#  loss_reduction_profile1.png
#  loss_reduction_profile_Inception_V3.png
#  models/
#  __pycache__/
#  Resnet50_model.weights.best.hdf5
#  results.csv

# %% [markdown]
# ### Download the datasets and unzip into data folder

# %%
# !wget "https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/test.zip"

# %%
# !unzip '/gdrive/My Drive/Colab Notebooks/test.zip' -d '/gdrive/My Drive/Colab Notebooks/data/'

# %%
# !wget "https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/train.zip"

# %%
# !unzip '/gdrive/My Drive/Colab Notebooks/train.zip' -d '/gdrive/My Drive/Colab Notebooks/data/'

# %%
# !wget "https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/valid.zip"

# %%
# !unzip '/gdrive/My Drive/Colab Notebooks/valid.zip' -d '/gdrive/My Drive/Colab Notebooks/data/'

# %% [markdown]
# # change KERNEL to torch_py37
# ### Import the necessary librairies and count available samples

# %%
import numpy as np
import os
import sys
import time
from glob import glob
import pandas as pd
from PIL import Image, ImageFile
from collections import OrderedDict
import matplotlib.pyplot as plt

from tqdm.notebook import tqdm
from tqdm import tnrange
from collections import OrderedDict

import torch
import torch.optim as optim
from torch.autograd import Variable
from torchvision import datasets
import torchvision.transforms as transforms
import torchvision.models as models
import torch.nn as nn
# !pip install pytorch_model_summary
from pytorch_model_summary import summary  # upgraded version of torchsummary
# Out:
# Requirement already satisfied: pytorch_model_summary in /usr/local/lib/python3.6/dist-packages (0.1.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (from pytorch_model_summary) (1.6.0+cu101)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from pytorch_model_summary) (4.41.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from pytorch_model_summary) (1.18.5)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch->pytorch_model_summary) (0.16.0)

# %% [markdown]
# ### Set the device as CUDA or CPU

# %%
# check if CUDA is available
use_cuda = torch.cuda.is_available()

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

if use_cuda:
    print('Default GPU Device: {}'.format(torch.cuda.get_device_name(0)))
else:
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
# Out:
# Default GPU Device: Tesla K80

# %% [markdown]
# ### Explore the data

# %%
# load filenames for images
train_files = []
valid_files = []
test_files = []
files = ['train_files', 'valid_files', 'test_files']
mypath = os.getcwd()

for file in files:
    folder = file.split('_')[0]
    path = os.path.join(mypath, 'data', folder)

    for dir_ in os.listdir(path):
        subpath=os.path.join(path, dir_)
        if folder == 'train':
            train_files.extend(glob(subpath+'/*'))
        elif folder == 'valid':
            valid_files.extend(glob(subpath+'/*'))
        else:
            test_files.extend(glob(subpath+'/*'))
            
# print number of images in each dataset
print('There are %d total train images.' % len(train_files))
print('There are %d total validation images.' % len(valid_files))
print('There are %d total test images.' % len(test_files))

plt.barh(['train', 'validation', 'test'], [len(train_files), len(valid_files), len(test_files)])
plt.title('images per class')
plt.show()
# Out:
# There are 4035 total train images.
# There are 150 total validation images.
# There are 600 total test images.

# %% [markdown]
# ### Display a few of the samples

# %%
import cv2                
import matplotlib.pyplot as plt                           

plt.figure(figsize=(18,9))
for index, img_path in enumerate(train_files[:3]):
    plt.subplot(1,3, index+1)
    # images are within [0,255] and must be scaled to [0,1] for pytorch pretrained models
    img = cv2.imread(img_path)
    #print(img_path.split('dermatologist-ai-master')[1], '\timg shape:', img.shape, '\tmin/max:', img.min(axis=(0,1)), img.max(axis=(0,1)))
    print(img_path.split('Dermatologist_ai')[1], '\timg shape:', img.shape, '\tmin/max:', img.min(axis=(0,1)), img.max(axis=(0,1)))
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.imshow(img_rgb)
plt.show()
# Out:
# /data/train/seborrheic_keratosis/ISIC_0012833.jpg 	img shape: (2000, 3008, 3) 	min/max: [0 1 1] [193 193 217]
# /data/train/seborrheic_keratosis/ISIC_0012840.jpg 	img shape: (2592, 3872, 3) 	min/max: [11 10  9] [255 255 255]
# /data/train/seborrheic_keratosis/ISIC_0012845.jpg 	img shape: (2000, 3008, 3) 	min/max: [35 29 27] [255 255 255]

# %%
# determine smallest image dimensions in Train dataset
h_min = 10000
w_min = 10000

for img_path in tqdm(train_files):
    img = cv2.imread(img_path)
    h, w, _ = img.shape
    if h < h_min:
        h_min = h
    if w < w_min:
        w_min = w

print('smallest dimensions in train dataset h x w: ', h_min,' x ', w_min)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=3644.0), HTML(value='')))
# smallest dimensions in train dataset h x w:  450  x  576

# %% [markdown]
#  ### DATA AUGMENTATION - train dataset is squewed towards Nevus
# - dataset augmented using ISIC database
#     - 165 additional Seborrheic Keratosis images
#     - 998 additional melanoma images
# - data augmentation performed on Seborrheic Keratosis to balance the dataset between classes

# %%
labels=['melanoma', 'nevus', 'seborrheic_keratosis']
counts=np.zeros(3).astype(np.int)
for index, label in enumerate(labels):
    path = os.path.join(mypath, 'data', 'train', label)
    counts[index] = len(os.listdir(path))
    print('train set: number of ',label,' images: ',counts[index])

plt.bar(labels, counts, width = 0.3)
plt.ylim(bottom=0)
plt.show()
# Out:
# train set: number of  melanoma  images:  1406
# train set: number of  nevus  images:  1372
# train set: number of  seborrheic_keratosis  images:  1257

# %% [markdown]
# # Data augmentation to balance under-represented classes
# # RUN ONCE ONLY

# %%
from PIL import Image

path = os.path.join(mypath, 'data', 'train', 'seborrheic_keratosis')
list_of_imgs = os.listdir(path)
counth = 0
countv = 0
for index, file in enumerate(tqdm(list_of_imgs)):
    file_name = os.path.join(path,file)
    image = Image.open(file_name)
    
    # flip up-down using np.flipud
    up_down = image.transpose(method=Image.FLIP_TOP_BOTTOM)
    up_down.save(os.path.join(path,'imageflipV{}.jpeg'.format(index)), 'JPEG')
    countv+=1
    
    # flip up-down using np.flipud
    left_right = image.transpose(method=Image.FLIP_LEFT_RIGHT)
    left_right.save(os.path.join(path,'imageflipH{}.jpeg'.format(index)), 'JPEG')
    counth+=1
print('Images generated and saved to disk: {} Horizontal flip, {} vertical flip...{} images in total'.format(counth, countv, counth+countv))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=419.0), HTML(value='')))
# Images generated and saved to disk: 419 Horizontal flip, 419 vertical flip...838 images in total

# %% [markdown]
# # END DATA AUGMENTATION

# %%
# Train dataset post image augmentation
labels=['melanoma', 'nevus', 'seborrheic_keratosis']
counts=np.zeros(3).astype(np.int)
for index, label in enumerate(labels):
    path = os.path.join(mypath, 'data', 'train', label)
    counts[index] = len(os.listdir(path))
    print('train set: number of ',label,' images: ',counts[index])

plt.bar(labels, counts, width = 0.3)
plt.ylim(bottom=0)
plt.show()
# Out:
# train set: number of  melanoma  images:  1406
# train set: number of  nevus  images:  1372
# train set: number of  seborrheic_keratosis  images:  1257

# %%
# Let's calculate corrective weights to apply during training
# Calculate corrective weights for class imbalance
counts = counts.astype(np.float)
median_freq=np.median(counts)
class_weights=np.zeros_like(labels, dtype=np.float)
print('Corrective weights to account for dataset over-representation of Nevus')
for index, label in enumerate(labels):
    class_weights[index]=median_freq / counts[index]
    print(label,' : ',class_weights[index])

class_weights = torch.FloatTensor(class_weights)
if use_cuda:
    class_weights = class_weights.cuda()
# Out:
# Corrective weights to account for dataset over-representation of Nevus
# melanoma  :  0.9758179231863442
# nevus  :  1.0
# seborrheic_keratosis  :  1.0914876690533015

# %% [markdown]
# ### Set dataloader with appropriate image transformations. I use data augmentation

# %%
# Pytorch default backend for images are Pillow. when using ToTensor(), PyTorch automatically converts all images into [0,1]

def get_loaders (input_shape, batch_size_train, batch_size_val, batch_size_test, num_workers):
    
    data_dir = 'data/'
    train_dir = os.path.join(data_dir, 'train/')
    valid_dir = os.path.join(data_dir, 'valid/')
    test_dir = os.path.join(data_dir, 'test/')
    (img_dim_H,img_dim_W) = input_shape

    train_transform = transforms.Compose([transforms.Resize((img_dim_H,img_dim_W)),                                               
                                        transforms.RandomHorizontalFlip(0.5),
                                        transforms.RandomVerticalFlip(0.5),
                                        transforms.RandomRotation(45),
                                        transforms.ToTensor(),
                                        transforms.Normalize(mean=(0.485, 0.456, 0.406),
                                                            std=(0.229, 0.224, 0.225))])  
    
    valid_transform = transforms.Compose([transforms.Resize((img_dim_H,img_dim_W)),
                                        transforms.ToTensor(),
                                        transforms.Normalize(mean=(0.485, 0.456, 0.406),
                                                            std=(0.229, 0.224, 0.225))])

    test_transform = transforms.Compose([transforms.Resize((img_dim_H,img_dim_W)),
                                      transforms.ToTensor(),
                                      transforms.Normalize(mean=(0.485, 0.456, 0.406),
                                                          std=(0.229, 0.224, 0.225))])

    train_data = datasets.ImageFolder(train_dir, transform=train_transform)
    valid_data = datasets.ImageFolder(valid_dir, transform=valid_transform)
    test_data = datasets.ImageFolder(test_dir, transform=test_transform)

    train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size_train, shuffle=True, num_workers=num_workers)
    valid_loader = torch.utils.data.DataLoader(valid_data, batch_size=batch_size_val, shuffle=True, num_workers=num_workers)
    test_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_size_test, shuffle=False, num_workers=num_workers)

    return {'train': train_loader, 'valid': valid_loader, 'test': test_loader}

# %% [markdown]
# ### (IMPLEMENTATION) Train and Validate the Model

# %%
ImageFile.LOAD_TRUNCATED_IMAGES = True

def train(n_epochs, loaders, model, optimizer, criterion, use_cuda, file_name, is_inception=False):
    """returns trained model"""
    # initialize tracker for minimum validation loss
    valid_loss_min = np.Inf
    running_train_loss = []
    running_val_loss = []
    start_time = time.time()
    
    for epoch in range(1, n_epochs+1):
        # initialize variables to monitor training and validation loss
        train_loss = 0.0
        valid_loss = 0.0
        av_loss_train = 0
        av_loss_val = 0
        
        previous_time = time.time()
        
        ###################
        # train the model #
        ###################
        model.train()
        for batch_idx, (data, target) in enumerate(loaders['train']):
            # move to GPU
            if use_cuda:
                data, target = data.cuda(), target.cuda()
            ## find the loss and update the model parameters accordingly
            optimizer.zero_grad()

            if is_inception:
              output, aux_output = model(data)
              loss1 = criterion(output, target)
              loss2 = criterion(aux_output, target)
              loss = loss1 + 0.4 * loss2                 # 0.4 is weight for auxillary classifier in Inception V3
            else:
              output = model(data)
              loss = criterion(output, target)

            loss.backward()
            optimizer.step()
            
            ## record the average training loss
            #train_loss = train_loss + ((1 / (batch_idx + 1)) * (loss.item() - train_loss))
            train_loss += loss.item() * len(target)
            av_loss_train = train_loss / ((batch_idx+1) * batch_size_train)
            
            # Get training statistics.
            current_time = time.time()
            stats = 'Epoch [%d/%d] Step [%d/%d]\t Loss: %.4f\t avg_Loss: %.4f\t exec_time: %d s\t train_time:\t %d h %d m' % (epoch, n_epochs, batch_idx+1, len(loaders['train']), loss.item(), av_loss_train, #train_loss,
                    (current_time - previous_time), (current_time-start_time)//3600, (current_time-start_time)//60-((current_time-start_time)//3600)*60)
            
            # Print training statistics (on same line).
            print('\r' + stats, end="")
            sys.stdout.flush()

            # Print training statistics (on different line).
            if (batch_idx+1) % print_every == 0:
                print('\r' + stats)
        
        ######################    
        # validate the model #
        ######################
        model.eval()
        dataset_size = 0
        running_corrects = 0
        
        for batch_idx, (data, target) in enumerate(loaders['valid']):
            # move to GPU
            if use_cuda:
                data, target = data.cuda(), target.cuda()
            ## update the average validation loss
            with torch.no_grad():
                output = model(data)
                loss = criterion(output, target)
                #valid_loss = valid_loss + ((1 / (batch_idx + 1)) * (loss.item() - valid_loss))
                valid_loss += loss.item() * target.size(0)
                av_loss_val = valid_loss / ((batch_idx+1) * batch_size_val)
            
                _, preds = torch.max(output, 1)
                running_corrects += torch.sum(preds == target.data)
                dataset_size += len(data)
        
        accuracy = torch.true_divide(running_corrects, dataset_size) * 100
        #batch_loss = train_loss / len(loaders['train'].dataset)
        # Get training/validation statistics        
        stats = 'Epoch [%d/%d]\t avg_train Loss: %.4f\t\t\t avg_validation Loss: %.4f\t val_accuracy: %.2f' % (epoch, n_epochs, av_loss_train, av_loss_val, accuracy)   # valid_loss,
            
        # Print validation statistics (on new line).
        print(stats)
        sys.stdout.flush()
        
        # store losses for later use
        running_train_loss.append(av_loss_train)  #train_loss
        running_val_loss.append(av_loss_val)    #valid_loss
        
        ## Save the model if validation loss has decreased
        if av_loss_val < valid_loss_min:
            valid_loss_min = av_loss_val
            save_file = os.path.join(save_path, file_name)
            torch.save(model.state_dict(), save_file)
            print('improved model saved to disk')
        
        
        #if valid_loss < valid_loss_min:
        #    valid_loss_min = valid_loss
            
        
        scheduler.step(valid_loss)
            
    # return trained model
    return model, running_train_loss, running_val_loss

# %%
### Calculate the accuracy
def test(loaders, model, criterion, use_cuda):

    # monitor test loss and accuracy
    test_loss = 0.
    correct = 0.
    
    class_correct = list(0. for i in range(num_classes))
    class_total = list(0. for i in range(num_classes))

    model.eval()
    
    for batch_idx, (data, targets) in enumerate(tqdm(loaders['test'])):
        # move to GPU
        if use_cuda:
            data, targets = data.cuda(), targets.cuda()
        # forward pass: compute predicted outputs by passing inputs to the model
        outputs = model(data)
        # calculate the loss
        loss = criterion(outputs, targets).item()
        # update average test loss 
        test_loss = test_loss + ((1 / (batch_idx + 1)) * (loss - test_loss))
        
        # convert output probabilities to predicted class
        output = torch.nn.functional.softmax(outputs, dim=1)
        _, preds = torch.max(output, dim=1)
        
        # compare predictions to true label
        correct_tensor = preds.eq(targets.view_as(preds))    # equivalent to tensor.view(preds.size())
        correct = np.squeeze(correct_tensor.numpy()) if not torch.cuda.is_available() else np.squeeze(correct_tensor.cpu().numpy())
        
        # calculate test accuracy for each object class
        for i in range(batch_size_test):
            label = targets[i]
            class_correct[label] += correct[i].item()
            class_total[label] += 1
            
    print('Test Loss: {:.6f}\n'.format(test_loss))
    
    for i in range(num_classes):
        if class_total[i] > 0:
            
            print('Test Accuracy of {}:'.format(labels[i]),
              ' {:.0f}%'.format(100 * class_correct[i] / class_total[i]).ljust(8,' '), 
              '({:.0f}/{:.0f})'.format(np.sum(class_correct[i]), np.sum(class_total[i])))
            
        else:
            print('Test Accuracy of {}: N/A (no training examples)'.format(labels[i]))
                      
    print('\nTest Accuracy (Overall):\t {:.0f}%'.format(100. * np.sum(class_correct) / np.sum(class_total)).expandtabs(71),
      '\t({:.0f}/{:.0f})'.format(np.sum(class_correct), np.sum(class_total)).expandtabs(4))

# %%
def plot_loss(model, train_loss, val_loss):
    plt.plot(np.arange(1, n_epochs+1,1), train_loss, label='average train loss')
    plt.plot(np.arange(1, n_epochs+1,1), val_loss, label='average validation loss')
    plt.xlabel('epochs')
    plt.ylabel('running losses')
    plt.title('loss reduction ' + model)
    plt.legend(loc='upper right')
    filename = 'loss_reduction_profile_'+model+'.png'
    plt.savefig(filename)
    plt.show()

# %% [markdown]
# ## Display example of inherence output format for get_results.py (performance evaluation)

# %%
true_labels = pd.read_csv("ground_truth.csv", sep=",", header=0, index_col=0)
print(list(true_labels))
true_labels.head(5)
# Out:
# ['task_1', 'task_2']
#                                      task_1  task_2
# Id
# data/test/melanoma/ISIC_0012258.jpg       1       0
# data/test/melanoma/ISIC_0012356.jpg       1       0
# data/test/melanoma/ISIC_0012369.jpg       1       0
# data/test/melanoma/ISIC_0012395.jpg       1       0
# data/test/melanoma/ISIC_0012425.jpg       1       0

# %% [markdown]
# ## Get predictions and prepare results file

# %%
def test_transform_img(img, input_img_dim):
    test_transform = transforms.Compose([transforms.Resize((input_img_dim[0],input_img_dim[1])),
                                      #transforms.CenterCrop((input_img_dim[0],input_img_dim[1])),
                                      transforms.ToTensor(),
                                      transforms.Normalize(mean=(0.485, 0.456, 0.406),
                                                          std=(0.229, 0.224, 0.225))
                                        ])
    return test_transform(img)

def get_image(img_path, input_img_dim):
    image = Image.open(img_path)
    image = test_transform_img(image, input_img_dim)
    image = image.requires_grad_(True)
    #image = torch.tensor(image, requires_grad=True)
    image = image.unsqueeze(0)                         # add batch dimension
    return image

# %%
def get_predictions(model, path_to_files, input_img_dim=(224,224)):
    if use_cuda:
        model = model.cuda()
    model.eval()
    score_1 = []
    score_2 = []
    for img_path in tqdm(path_to_files):
        img = get_image(img_path, input_img_dim)
        if use_cuda:
            img = img.cuda()
        pred = model(img).cpu().detach().numpy()
        score_1.append(float(pred[0][0]))
        score_2.append(float(pred[0][2]))
    return score_1, score_2

# %%
import csv
    
def get_scores(model, input_img_dim):
    
    print("\ngetting predictions on all test images:")
    score_1, score_2 = get_predictions(model, test_files, input_img_dim)
    
    print("writing score csv file")
    with open('results.csv', 'w', newline='') as csvfile:
        doc = csv.writer(csvfile)
        doc.writerow(['Id', 'task_1', 'task_2'])
        for i in range(len(test_files)):
            doc.writerow([test_files[i], score_1[i], score_2[i]])
        
    plot_scores()

# %% [markdown]
# ### Evaluate predictions and Plot scores

# %%
import sys
import itertools
import get_results as results

def plot_scores():
    
    threshold = 0.5 

    # get ground truth labels for test dataset
    truth = pd.read_csv('ground_truth.csv')
    y_true = truth[["task_1", "task_2"]].values

    # get model predictions for test dataset
    y_pred = pd.read_csv('results.csv')
    y_pred = y_pred[["task_1", "task_2"]].values

    # plot ROC curves and print scores
    results.plot_roc_auc(y_true, y_pred)
    
    # plot confusion matrix
    classes = ['benign', 'malignant']
    results.plot_confusion_matrix(y_true[:,0], y_pred[:,0], threshold, classes)

# %% [markdown]
# # (IMPLEMENTATION) Model Architecture
# ---
# In this section, we use a [pre-trained model](http://pytorch.org/docs/master/torchvision/models.html).
#
# # Obtain Pre-trained VGG-16 Model
#
# The code cell below downloads the VGG-16 model, along with weights that have been trained on [ImageNet](http://www.image-net.org/), a very large, very popular dataset used for image classification and other vision tasks.  ImageNet contains over 10 million URLs, each linking to an image containing an object from one of [1000 categories](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a).
# You are free to explore other pre-trained networks (such as [Inception-v3](http://pytorch.org/docs/master/torchvision/models.html#inception-v3), [ResNet-50](http://pytorch.org/docs/master/torchvision/models.html#id3), etc).

# %%
#from torchsummary import summary          # original version torchsummary
from pytorch_model_summary import summary  # upgraded version of torchsummary

num_classes = 3                            # melanoma, nevus, keratosis

## Specify model architecture 
model_VGG = models.vgg16(pretrained=True)

for param in model_VGG.features.parameters():                     # freeze feature parameters of pre-trained VGG16 model
    param.requires_grad = False

model_VGG.classifier[6] = nn.Linear(4096, num_classes)   # replace last layer with proper output dimensions

# Print summary and move to GPU/CPU
if use_cuda:
    model_VGG = model_VGG.cuda()
    summary(model_VGG, torch.zeros((1, 3, 224, 224)).to(device), show_input=False, show_hierarchical=False, print_summary=True)
else:
    summary(model_VGG, torch.zeros((1, 3, 224, 224)), show_input=False, show_hierarchical=False, print_summary=True)
# Out:
# -------------------------------------------------------------------------------
#            Layer (type)           Output Shape         Param #     Tr. Param #
# ===============================================================================
#                Conv2d-1      [1, 64, 224, 224]           1,792               0
#                  ReLU-2      [1, 64, 224, 224]               0               0
#                Conv2d-3      [1, 64, 224, 224]          36,928               0
#                  ReLU-4      [1, 64, 224, 224]               0               0
#             MaxPool2d-5      [1, 64, 112, 112]               0               0
#                Conv2d-6     [1, 128, 112, 112]          73,856               0
#                  ReLU-7     [1, 128, 112, 112]               0               0
#                Conv2d-8     [1, 128, 112, 112]         147,584               0
#                  ReLU-9     [1, 128, 112, 112]               0               0
#            MaxPool2d-10       [1, 128, 56, 56]               0               0
#               Conv2d-11       [1, 256, 56, 56]         295,168               0
#                 ReLU-12       [1, 256, 56, 56]               0               0
#               Conv2d-13       [1, 256, 56, 56]         590,080               0
#                 ReLU-14       [1, 256, 56, 56]               0               0
#               Conv2d-15       [1, 256, 56, 56]         590,080               0
#                 ReLU-16       [1, 256, 56, 56]               0               0
#            MaxPool2d-17       [1, 256, 28, 28]               0               0
#               Conv2d-18       [1, 512, 28, 28]       1,180,160               0
#                 ReLU-19       [1, 512, 28, 28]               0               0
#               Conv2d-20       [1, 512, 28, 28]       2,359,808               0
#                 ReLU-21       [1, 512, 28, 28]               0               0
#               Conv2d-22       [1, 512, 28, 28]       2,359,808               0
#                 ReLU-23       [1, 512, 28, 28]               0               0
#            MaxPool2d-24       [1, 512, 14, 14]               0               0
#               Conv2d-25       [1, 512, 14, 14]       2,359,808               0
#                 ReLU-26       [1, 512, 14, 14]               0               0
#               Conv2d-27       [1, 512, 14, 14]       2,359,808               0
#                 ReLU-28       [1, 512, 14, 14]               0               0
#               Conv2d-29       [1, 512, 14, 14]       2,359,808               0
#                 ReLU-30       [1, 512, 14, 14]               0               0
#            MaxPool2d-31         [1, 512, 7, 7]               0               0
#    AdaptiveAvgPool2d-32         [1, 512, 7, 7]               0               0
#               Linear-33              [1, 4096]     102,764,544     102,764,544
#                 ReLU-34              [1, 4096]               0               0
#              Dropout-35              [1, 4096]               0               0
#               Linear-36              [1, 4096]      16,781,312      16,781,312
#                 ReLU-37              [1, 4096]               0               0
#              Dropout-38              [1, 4096]               0               0
#               Linear-39                 [1, 3]          12,291          12,291
# ===============================================================================
# Total params: 134,272,835
# Trainable params: 119,558,147
# Non-trainable params: 14,714,688
# -------------------------------------------------------------------------------

# %% [markdown]
# ### (IMPLEMENTATION) Specify Loss Function and Optimizer

# %%
image_size = (350,450)  # max(450,576)
num_workers = 0
batch_size_train = 10
batch_size_val = 10
batch_size_test = 10
loaders=get_loaders(image_size, batch_size_train, batch_size_val, batch_size_test, num_workers)

# %%
criterion = nn.CrossEntropyLoss()     # In Pytorch, CrossEntropyLoss combines a Logsoftmax with a NLLLoss
optimizer = optim.Adam(model_VGG.classifier.parameters(), lr=0.00001, betas=(0.9,0.999))
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=2)

# %%
# train the model
n_epochs = 10
print_every = 317
save_path = './models'

model_VGG, train_loss, val_loss = train(n_epochs, loaders, model_VGG, optimizer, criterion, use_cuda, 'model_VGG_fine3.pt', is_inception=False)
# Out:
# Epoch [1/10] Step [315/316]	 Loss: 0.3890	 avg_Loss: 0.5901	 exec_time: 469 s	 train_time:	 0 h 7 mEpoch [1/10]	 avg_train Loss: 0.5901			 avg_validation Loss: 0.6198
# improved model saved to disk
# Epoch [2/10] Step [315/316]	 Loss: 0.4758	 avg_Loss: 0.5965	 exec_time: 501 s	 train_time:	 0 h 16 mEpoch [2/10]	 avg_train Loss: 0.5965			 avg_validation Loss: 0.6205
# Epoch [3/10] Step [315/316]	 Loss: 0.4301	 avg_Loss: 0.5866	 exec_time: 508 s	 train_time:	 0 h 25 mEpoch [3/10]	 avg_train Loss: 0.5866			 avg_validation Loss: 0.6179
# improved model saved to disk
# Epoch [4/10] Step [315/316]	 Loss: 0.7511	 avg_Loss: 0.5795	 exec_time: 498 s	 train_time:	 0 h 34 mEpoch [4/10]	 avg_train Loss: 0.5795			 avg_validation Loss: 0.6158
# improved model saved to disk
# Epoch [5/10] Step [315/316]	 Loss: 0.4864	 avg_Loss: 0.5845	 exec_time: 508 s	 train_time:	 0 h 43 mEpoch [5/10]	 avg_train Loss: 0.5845			 avg_validation Loss: 0.6149
# improved model saved to disk
# Epoch [6/10] Step [315/316]	 Loss: 0.3125	 avg_Loss: 0.5881	 exec_time: 508 s	 train_time:	 0 h 53 mEpoch [6/10]	 avg_train Loss: 0.5881			 avg_validation Loss: 0.6149
# improved model saved to disk
# Epoch [7/10] Step [315/316]	 Loss: 0.3186	 avg_Loss: 0.5868	 exec_time: 507 s	 train_time:	 1 h 2 mmEpoch [7/10]	 avg_train Loss: 0.5868			 avg_validation Loss: 0.6144
# improved model saved to disk
# Epoch [8/10] Step [315/316]	 Loss: 0.3447	 avg_Loss: 0.5891	 exec_time: 509 s	 train_time:	 1 h 11 mEpoch [8/10]	 avg_train Loss: 0.5891			 avg_validation Loss: 0.6159
# Epoch [9/10] Step [315/316]	 Loss: 0.3714	 avg_Loss: 0.5843	 exec_time: 525 s	 train_time:	 1 h 20 mEpoch [9/10]	 avg_train Loss: 0.5843			 avg_validation Loss: 0.6149
# Epoch [10/10] Step [315/316]	 Loss: 0.7429	 avg_Loss: 0.5837	 exec_time: 507 s	 train_time:	 1 h 29 mEpoch [10/10]	 avg_train Loss: 0.5837			 avg_validation Loss: 0.6141
# improved model saved to disk

# %%
# Display loss reduction profile
plot_loss('VGG16', train_loss, val_loss)

# %% [markdown]
# ### (IMPLEMENTATION) Test the Model
#
# Calculate and print the test loss and accuracy.

# %%
# load the model that got the best validation accuracy (uncomment the line below)
if torch.cuda.is_available():
    model_VGG.load_state_dict(torch.load('models/model_VGG.pt'))
else:
    model_VGG.load_state_dict(torch.load('models/model_VGG.pt', map_location=torch.device('cpu')))

# %%
with torch.no_grad():
    test(loaders, model_VGG, criterion, use_cuda)
    get_scores(model_VGG, (450,576))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=60.0), HTML(value='')))
# Test Loss: 0.937992
#
# Test Accuracy of melanoma:  50%     (58/117)
# Test Accuracy of nevus:  54%     (213/393)
# Test Accuracy of seborrheic_keratosis:  47%     (42/90)
#
# Test Accuracy (Overall):                                                52%     (313/600)
#
# getting predictions on all test images:
# HBox(children=(FloatProgress(value=0.0, max=600.0), HTML(value='')))
# writing score csv file
# Category 1 Score: 0.568
# Category 2 Score: 0.801
# Category 3 Score: 0.684

# %% [markdown]
# # Obtain Pre-trained Inception V3 Model
# The code cell below downloads the model, along with weights that have been trained on ImageNet, a very large, very popular dataset used for image classification and other vision tasks. ImageNet contains over 10 million URLs, each linking to an image containing an object from one of 1000 categories.

# %%
## Specify model architecture 
num_classes = 3

model_inception = models.inception_v3(pretrained=True, aux_logits=True)             # Be careful, InceptionV3 expects (299,299) sized images and has auxiliary output

model_inception = model_inception.to(device)
# Out:
# Downloading: "https://download.pytorch.org/models/inception_v3_google-1a9a5a14.pth" to /root/.cache/torch/hub/checkpoints/inception_v3_google-1a9a5a14.pth
# HBox(children=(FloatProgress(value=0.0, max=108857766.0), HTML(value='')))

# %% [markdown]
# ### Modify both output layers of Inception model for the classification task
# - aux_ouput
# - fully connected layer

# %%
def count_parameters(model):
    total_params = 0
    #for index, parameter in enumerate(model.parameters()):
    for index, (name, parameter) in enumerate(model.named_parameters()):
        #if not parameter.requires_grad: continue
        param = parameter.numel()
        print('weight n°',index, '\tlayer:', name, '\t\t#parameters ', param)
        total_params+=param
    print(f"\nTotal Trainable Params: {total_params}")

# %%
 for param in model_inception.parameters():               # freeze feature parameters of pre-trained model
    param.requires_grad = False


model_inception.AuxLogits.fc = nn.Linear(768, num_classes)

BasicConv2d = nn.Sequential(OrderedDict([('conv', nn.Conv2d(2048, 192, kernel_size=(1,1), stride=(1,1))),
                                         ('bn', nn.BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True))]))

classifier = nn.Sequential(OrderedDict([ ('fc1', nn.Linear(2048, 512)),     
                                         ('relu', nn.ReLU()),
                                        ('drop', nn.Dropout(0.4)),
                                         ('fc2', nn.Linear(512, num_classes)) 
                                         ]))                                                # ('output', nn.Softmax(dim=1))

model_inception.Mixed_7c.branch_pool = BasicConv2d
model_inception.fc = classifier

print(summary(model_inception.to(device), torch.zeros((1, 3, 299, 299)).to(device), show_input=False, show_hierarchical=False, print_summary=False))

#for module, layer in model_inception.named_modules():
#    print(module, layer)
# Out:
# ------------------------------------------------------------------------------
#            Layer (type)          Output Shape         Param #     Tr. Param #
# ==============================================================================
#           BasicConv2d-1     [1, 32, 149, 149]             928               0
#           BasicConv2d-2     [1, 32, 147, 147]           9,280               0
#           BasicConv2d-3     [1, 64, 147, 147]          18,560               0
#             MaxPool2d-4       [1, 64, 73, 73]               0               0
#           BasicConv2d-5       [1, 80, 73, 73]           5,280               0
#           BasicConv2d-6      [1, 192, 71, 71]         138,624               0
#             MaxPool2d-7      [1, 192, 35, 35]               0               0
#            InceptionA-8      [1, 256, 35, 35]         255,904               0
#            InceptionA-9      [1, 288, 35, 35]         277,472               0
#           InceptionA-10      [1, 288, 35, 35]         285,152               0
#           InceptionB-11      [1, 768, 17, 17]       1,153,280               0
#           InceptionC-12      [1, 768, 17, 17]       1,297,408               0
#           InceptionC-13      [1, 768, 17, 17]       1,691,008               0
#           InceptionC-14      [1, 768, 17, 17]       1,691,008               0
#           InceptionC-15      [1, 768, 17, 17]       2,141,952               0
#           InceptionD-16       [1, 1280, 8, 8]       1,698,304               0
#           InceptionE-17       [1, 2048, 8, 8]       5,044,608               0
#           InceptionE-18       [1, 2048, 8, 8]       6,076,992       6,076,992
#    AdaptiveAvgPool2d-19       [1, 2048, 1, 1]               0               0
#              Dropout-20       [1, 2048, 1, 1]               0               0
#               Linear-21              [1, 512]       1,049,088       1,049,088
#                 ReLU-22              [1, 512]               0               0
#              Dropout-23              [1, 512]               0               0
#               Linear-24                [1, 3]           1,539           1,539
# ==============================================================================
# Total params: 22,836,387
# Trainable params: 7,127,619
# Non-trainable params: 15,708,768
# ------------------------------------------------------------------------------

# %%
count_parameters(model_inception)
# Out:
# weight n° 0 	layer: Conv2d_1a_3x3.conv.weight 		#parameters  864
# weight n° 1 	layer: Conv2d_1a_3x3.bn.weight 		#parameters  32
# weight n° 2 	layer: Conv2d_1a_3x3.bn.bias 		#parameters  32
# weight n° 3 	layer: Conv2d_2a_3x3.conv.weight 		#parameters  9216
# weight n° 4 	layer: Conv2d_2a_3x3.bn.weight 		#parameters  32
# weight n° 5 	layer: Conv2d_2a_3x3.bn.bias 		#parameters  32
# weight n° 6 	layer: Conv2d_2b_3x3.conv.weight 		#parameters  18432
# weight n° 7 	layer: Conv2d_2b_3x3.bn.weight 		#parameters  64
# weight n° 8 	layer: Conv2d_2b_3x3.bn.bias 		#parameters  64
# weight n° 9 	layer: Conv2d_3b_1x1.conv.weight 		#parameters  5120
# weight n° 10 	layer: Conv2d_3b_1x1.bn.weight 		#parameters  80
# weight n° 11 	layer: Conv2d_3b_1x1.bn.bias 		#parameters  80
# weight n° 12 	layer: Conv2d_4a_3x3.conv.weight 		#parameters  138240
# weight n° 13 	layer: Conv2d_4a_3x3.bn.weight 		#parameters  192
# weight n° 14 	layer: Conv2d_4a_3x3.bn.bias 		#parameters  192
# weight n° 15 	layer: Mixed_5b.branch1x1.conv.weight 		#parameters  12288
# weight n° 16 	layer: Mixed_5b.branch1x1.bn.weight 		#parameters  64
# weight n° 17 	layer: Mixed_5b.branch1x1.bn.bias 		#parameters  64
# weight n° 18 	layer: Mixed_5b.branch5x5_1.conv.weight 		#parameters  9216
# weight n° 19 	layer: Mixed_5b.branch5x5_1.bn.weight 		#parameters  48
# weight n° 20 	layer: Mixed_5b.branch5x5_1.bn.bias 		#parameters  48
# weight n° 21 	layer: Mixed_5b.branch5x5_2.conv.weight 		#parameters  76800
# weight n° 22 	layer: Mixed_5b.branch5x5_2.bn.weight 		#parameters  64
# weight n° 23 	layer: Mixed_5b.branch5x5_2.bn.bias 		#parameters  64
# weight n° 24 	layer: Mixed_5b.branch3x3dbl_1.conv.weight 		#parameters  12288
# weight n° 25 	layer: Mixed_5b.branch3x3dbl_1.bn.weight 		#parameters  64
# weight n° 26 	layer: Mixed_5b.branch3x3dbl_1.bn.bias 		#parameters  64
# weight n° 27 	layer: Mixed_5b.branch3x3dbl_2.conv.weight 		#parameters  55296
# weight n° 28 	layer: Mixed_5b.branch3x3dbl_2.bn.weight 		#parameters  96
# weight n° 29 	layer: Mixed_5b.branch3x3dbl_2.bn.bias 		#parameters  96
# weight n° 30 	layer: Mixed_5b.branch3x3dbl_3.conv.weight 		#parameters  82944
# weight n° 31 	layer: Mixed_5b.branch3x3dbl_3.bn.weight 		#parameters  96
# weight n° 32 	layer: Mixed_5b.branch3x3dbl_3.bn.bias 		#parameters  96
# weight n° 33 	layer: Mixed_5b.branch_pool.conv.weight 		#parameters  6144
# weight n° 34 	layer: Mixed_5b.branch_pool.bn.weight 		#parameters  32
# weight n° 35 	layer: Mixed_5b.branch_pool.bn.bias 		#parameters  32
# weight n° 36 	layer: Mixed_5c.branch1x1.conv.weight 		#parameters  16384
# weight n° 37 	layer: Mixed_5c.branch1x1.bn.weight 		#parameters  64
# weight n° 38 	layer: Mixed_5c.branch1x1.bn.bias 		#parameters  64
# weight n° 39 	layer: Mixed_5c.branch5x5_1.conv.weight 		#parameters  12288
# weight n° 40 	layer: Mixed_5c.branch5x5_1.bn.weight 		#parameters  48
# weight n° 41 	layer: Mixed_5c.branch5x5_1.bn.bias 		#parameters  48
# weight n° 42 	layer: Mixed_5c.branch5x5_2.conv.weight 		#parameters  76800
# weight n° 43 	layer: Mixed_5c.branch5x5_2.bn.weight 		#parameters  64
# weight n° 44 	layer: Mixed_5c.branch5x5_2.bn.bias 		#parameters  64
# weight n° 45 	layer: Mixed_5c.branch3x3dbl_1.conv.weight 		#parameters  16384
# weight n° 46 	layer: Mixed_5c.branch3x3dbl_1.bn.weight 		#parameters  64
# weight n° 47 	layer: Mixed_5c.branch3x3dbl_1.bn.bias 		#parameters  64
# weight n° 48 	layer: Mixed_5c.branch3x3dbl_2.conv.weight 		#parameters  55296
# weight n° 49 	layer: Mixed_5c.branch3x3dbl_2.bn.weight 		#parameters  96
# weight n° 50 	layer: Mixed_5c.branch3x3dbl_2.bn.bias 		#parameters  96
# weight n° 51 	layer: Mixed_5c.branch3x3dbl_3.conv.weight 		#parameters  82944
# weight n° 52 	layer: Mixed_5c.branch3x3dbl_3.bn.weight 		#parameters  96
# weight n° 53 	layer: Mixed_5c.branch3x3dbl_3.bn.bias 		#parameters  96
# weight n° 54 	layer: Mixed_5c.branch_pool.conv.weight 		#parameters  16384
# weight n° 55 	layer: Mixed_5c.branch_pool.bn.weight 		#parameters  64
# weight n° 56 	layer: Mixed_5c.branch_pool.bn.bias 		#parameters  64
# weight n° 57 	layer: Mixed_5d.branch1x1.conv.weight 		#parameters  18432
# weight n° 58 	layer: Mixed_5d.branch1x1.bn.weight 		#parameters  64
# weight n° 59 	layer: Mixed_5d.branch1x1.bn.bias 		#parameters  64
# weight n° 60 	layer: Mixed_5d.branch5x5_1.conv.weight 		#parameters  13824
# weight n° 61 	layer: Mixed_5d.branch5x5_1.bn.weight 		#parameters  48
# weight n° 62 	layer: Mixed_5d.branch5x5_1.bn.bias 		#parameters  48
# weight n° 63 	layer: Mixed_5d.branch5x5_2.conv.weight 		#parameters  76800
# weight n° 64 	layer: Mixed_5d.branch5x5_2.bn.weight 		#parameters  64
# weight n° 65 	layer: Mixed_5d.branch5x5_2.bn.bias 		#parameters  64
# weight n° 66 	layer: Mixed_5d.branch3x3dbl_1.conv.weight 		#parameters  18432
# weight n° 67 	layer: Mixed_5d.branch3x3dbl_1.bn.weight 		#parameters  64
# weight n° 68 	layer: Mixed_5d.branch3x3dbl_1.bn.bias 		#parameters  64
# weight n° 69 	layer: Mixed_5d.branch3x3dbl_2.conv.weight 		#parameters  55296
# weight n° 70 	layer: Mixed_5d.branch3x3dbl_2.bn.weight 		#parameters  96
# weight n° 71 	layer: Mixed_5d.branch3x3dbl_2.bn.bias 		#parameters  96
# weight n° 72 	layer: Mixed_5d.branch3x3dbl_3.conv.weight 		#parameters  82944
# weight n° 73 	layer: Mixed_5d.branch3x3dbl_3.bn.weight 		#parameters  96
# weight n° 74 	layer: Mixed_5d.branch3x3dbl_3.bn.bias 		#parameters  96
# weight n° 75 	layer: Mixed_5d.branch_pool.conv.weight 		#parameters  18432
# weight n° 76 	layer: Mixed_5d.branch_pool.bn.weight 		#parameters  64
# weight n° 77 	layer: Mixed_5d.branch_pool.bn.bias 		#parameters  64
# weight n° 78 	layer: Mixed_6a.branch3x3.conv.weight 		#parameters  995328
# weight n° 79 	layer: Mixed_6a.branch3x3.bn.weight 		#parameters  384
# weight n° 80 	layer: Mixed_6a.branch3x3.bn.bias 		#parameters  384
# weight n° 81 	layer: Mixed_6a.branch3x3dbl_1.conv.weight 		#parameters  18432
# weight n° 82 	layer: Mixed_6a.branch3x3dbl_1.bn.weight 		#parameters  64
# weight n° 83 	layer: Mixed_6a.branch3x3dbl_1.bn.bias 		#parameters  64
# weight n° 84 	layer: Mixed_6a.branch3x3dbl_2.conv.weight 		#parameters  55296
# weight n° 85 	layer: Mixed_6a.branch3x3dbl_2.bn.weight 		#parameters  96
# weight n° 86 	layer: Mixed_6a.branch3x3dbl_2.bn.bias 		#parameters  96
# weight n° 87 	layer: Mixed_6a.branch3x3dbl_3.conv.weight 		#parameters  82944
# weight n° 88 	layer: Mixed_6a.branch3x3dbl_3.bn.weight 		#parameters  96
# weight n° 89 	layer: Mixed_6a.branch3x3dbl_3.bn.bias 		#parameters  96
# weight n° 90 	layer: Mixed_6b.branch1x1.conv.weight 		#parameters  147456
# weight n° 91 	layer: Mixed_6b.branch1x1.bn.weight 		#parameters  192
# weight n° 92 	layer: Mixed_6b.branch1x1.bn.bias 		#parameters  192
# weight n° 93 	layer: Mixed_6b.branch7x7_1.conv.weight 		#parameters  98304
# weight n° 94 	layer: Mixed_6b.branch7x7_1.bn.weight 		#parameters  128
# weight n° 95 	layer: Mixed_6b.branch7x7_1.bn.bias 		#parameters  128
# weight n° 96 	layer: Mixed_6b.branch7x7_2.conv.weight 		#parameters  114688
# weight n° 97 	layer: Mixed_6b.branch7x7_2.bn.weight 		#parameters  128
# weight n° 98 	layer: Mixed_6b.branch7x7_2.bn.bias 		#parameters  128
# weight n° 99 	layer: Mixed_6b.branch7x7_3.conv.weight 		#parameters  172032
# weight n° 100 	layer: Mixed_6b.branch7x7_3.bn.weight 		#parameters  192
# weight n° 101 	layer: Mixed_6b.branch7x7_3.bn.bias 		#parameters  192
# weight n° 102 	layer: Mixed_6b.branch7x7dbl_1.conv.weight 		#parameters  98304
# weight n° 103 	layer: Mixed_6b.branch7x7dbl_1.bn.weight 		#parameters  128
# weight n° 104 	layer: Mixed_6b.branch7x7dbl_1.bn.bias 		#parameters  128
# weight n° 105 	layer: Mixed_6b.branch7x7dbl_2.conv.weight 		#parameters  114688
# weight n° 106 	layer: Mixed_6b.branch7x7dbl_2.bn.weight 		#parameters  128
# weight n° 107 	layer: Mixed_6b.branch7x7dbl_2.bn.bias 		#parameters  128
# weight n° 108 	layer: Mixed_6b.branch7x7dbl_3.conv.weight 		#parameters  114688
# weight n° 109 	layer: Mixed_6b.branch7x7dbl_3.bn.weight 		#parameters  128
# weight n° 110 	layer: Mixed_6b.branch7x7dbl_3.bn.bias 		#parameters  128
# weight n° 111 	layer: Mixed_6b.branch7x7dbl_4.conv.weight 		#parameters  114688
# weight n° 112 	layer: Mixed_6b.branch7x7dbl_4.bn.weight 		#parameters  128
# weight n° 113 	layer: Mixed_6b.branch7x7dbl_4.bn.bias 		#parameters  128
# weight n° 114 	layer: Mixed_6b.branch7x7dbl_5.conv.weight 		#parameters  172032
# weight n° 115 	layer: Mixed_6b.branch7x7dbl_5.bn.weight 		#parameters  192
# weight n° 116 	layer: Mixed_6b.branch7x7dbl_5.bn.bias 		#parameters  192
# weight n° 117 	layer: Mixed_6b.branch_pool.conv.weight 		#parameters  147456
# weight n° 118 	layer: Mixed_6b.branch_pool.bn.weight 		#parameters  192
# weight n° 119 	layer: Mixed_6b.branch_pool.bn.bias 		#parameters  192
# weight n° 120 	layer: Mixed_6c.branch1x1.conv.weight 		#parameters  147456
# weight n° 121 	layer: Mixed_6c.branch1x1.bn.weight 		#parameters  192
# weight n° 122 	layer: Mixed_6c.branch1x1.bn.bias 		#parameters  192
# weight n° 123 	layer: Mixed_6c.branch7x7_1.conv.weight 		#parameters  122880
# weight n° 124 	layer: Mixed_6c.branch7x7_1.bn.weight 		#parameters  160
# weight n° 125 	layer: Mixed_6c.branch7x7_1.bn.bias 		#parameters  160
# weight n° 126 	layer: Mixed_6c.branch7x7_2.conv.weight 		#parameters  179200
# weight n° 127 	layer: Mixed_6c.branch7x7_2.bn.weight 		#parameters  160
# weight n° 128 	layer: Mixed_6c.branch7x7_2.bn.bias 		#parameters  160
# weight n° 129 	layer: Mixed_6c.branch7x7_3.conv.weight 		#parameters  215040
# weight n° 130 	layer: Mixed_6c.branch7x7_3.bn.weight 		#parameters  192
# weight n° 131 	layer: Mixed_6c.branch7x7_3.bn.bias 		#parameters  192
# weight n° 132 	layer: Mixed_6c.branch7x7dbl_1.conv.weight 		#parameters  122880
# weight n° 133 	layer: Mixed_6c.branch7x7dbl_1.bn.weight 		#parameters  160
# weight n° 134 	layer: Mixed_6c.branch7x7dbl_1.bn.bias 		#parameters  160
# weight n° 135 	layer: Mixed_6c.branch7x7dbl_2.conv.weight 		#parameters  179200
# weight n° 136 	layer: Mixed_6c.branch7x7dbl_2.bn.weight 		#parameters  160
# weight n° 137 	layer: Mixed_6c.branch7x7dbl_2.bn.bias 		#parameters  160
# weight n° 138 	layer: Mixed_6c.branch7x7dbl_3.conv.weight 		#parameters  179200
# weight n° 139 	layer: Mixed_6c.branch7x7dbl_3.bn.weight 		#parameters  160
# weight n° 140 	layer: Mixed_6c.branch7x7dbl_3.bn.bias 		#parameters  160
# weight n° 141 	layer: Mixed_6c.branch7x7dbl_4.conv.weight 		#parameters  179200
# weight n° 142 	layer: Mixed_6c.branch7x7dbl_4.bn.weight 		#parameters  160
# weight n° 143 	layer: Mixed_6c.branch7x7dbl_4.bn.bias 		#parameters  160
# weight n° 144 	layer: Mixed_6c.branch7x7dbl_5.conv.weight 		#parameters  215040
# weight n° 145 	layer: Mixed_6c.branch7x7dbl_5.bn.weight 		#parameters  192
# weight n° 146 	layer: Mixed_6c.branch7x7dbl_5.bn.bias 		#parameters  192
# weight n° 147 	layer: Mixed_6c.branch_pool.conv.weight 		#parameters  147456
# weight n° 148 	layer: Mixed_6c.branch_pool.bn.weight 		#parameters  192
# weight n° 149 	layer: Mixed_6c.branch_pool.bn.bias 		#parameters  192
# weight n° 150 	layer: Mixed_6d.branch1x1.conv.weight 		#parameters  147456
# weight n° 151 	layer: Mixed_6d.branch1x1.bn.weight 		#parameters  192
# weight n° 152 	layer: Mixed_6d.branch1x1.bn.bias 		#parameters  192
# weight n° 153 	layer: Mixed_6d.branch7x7_1.conv.weight 		#parameters  122880
# weight n° 154 	layer: Mixed_6d.branch7x7_1.bn.weight 		#parameters  160
# weight n° 155 	layer: Mixed_6d.branch7x7_1.bn.bias 		#parameters  160
# weight n° 156 	layer: Mixed_6d.branch7x7_2.conv.weight 		#parameters  179200
# weight n° 157 	layer: Mixed_6d.branch7x7_2.bn.weight 		#parameters  160
# weight n° 158 	layer: Mixed_6d.branch7x7_2.bn.bias 		#parameters  160
# weight n° 159 	layer: Mixed_6d.branch7x7_3.conv.weight 		#parameters  215040
# weight n° 160 	layer: Mixed_6d.branch7x7_3.bn.weight 		#parameters  192
# weight n° 161 	layer: Mixed_6d.branch7x7_3.bn.bias 		#parameters  192
# weight n° 162 	layer: Mixed_6d.branch7x7dbl_1.conv.weight 		#parameters  122880
# weight n° 163 	layer: Mixed_6d.branch7x7dbl_1.bn.weight 		#parameters  160
# weight n° 164 	layer: Mixed_6d.branch7x7dbl_1.bn.bias 		#parameters  160
# weight n° 165 	layer: Mixed_6d.branch7x7dbl_2.conv.weight 		#parameters  179200
# weight n° 166 	layer: Mixed_6d.branch7x7dbl_2.bn.weight 		#parameters  160
# weight n° 167 	layer: Mixed_6d.branch7x7dbl_2.bn.bias 		#parameters  160
# weight n° 168 	layer: Mixed_6d.branch7x7dbl_3.conv.weight 		#parameters  179200
# weight n° 169 	layer: Mixed_6d.branch7x7dbl_3.bn.weight 		#parameters  160
# weight n° 170 	layer: Mixed_6d.branch7x7dbl_3.bn.bias 		#parameters  160
# weight n° 171 	layer: Mixed_6d.branch7x7dbl_4.conv.weight 		#parameters  179200
# weight n° 172 	layer: Mixed_6d.branch7x7dbl_4.bn.weight 		#parameters  160
# weight n° 173 	layer: Mixed_6d.branch7x7dbl_4.bn.bias 		#parameters  160
# weight n° 174 	layer: Mixed_6d.branch7x7dbl_5.conv.weight 		#parameters  215040
# weight n° 175 	layer: Mixed_6d.branch7x7dbl_5.bn.weight 		#parameters  192
# weight n° 176 	layer: Mixed_6d.branch7x7dbl_5.bn.bias 		#parameters  192
# weight n° 177 	layer: Mixed_6d.branch_pool.conv.weight 		#parameters  147456
# weight n° 178 	layer: Mixed_6d.branch_pool.bn.weight 		#parameters  192
# weight n° 179 	layer: Mixed_6d.branch_pool.bn.bias 		#parameters  192
# weight n° 180 	layer: Mixed_6e.branch1x1.conv.weight 		#parameters  147456
# weight n° 181 	layer: Mixed_6e.branch1x1.bn.weight 		#parameters  192
# weight n° 182 	layer: Mixed_6e.branch1x1.bn.bias 		#parameters  192
# weight n° 183 	layer: Mixed_6e.branch7x7_1.conv.weight 		#parameters  147456
# weight n° 184 	layer: Mixed_6e.branch7x7_1.bn.weight 		#parameters  192
# weight n° 185 	layer: Mixed_6e.branch7x7_1.bn.bias 		#parameters  192
# weight n° 186 	layer: Mixed_6e.branch7x7_2.conv.weight 		#parameters  258048
# weight n° 187 	layer: Mixed_6e.branch7x7_2.bn.weight 		#parameters  192
# weight n° 188 	layer: Mixed_6e.branch7x7_2.bn.bias 		#parameters  192
# weight n° 189 	layer: Mixed_6e.branch7x7_3.conv.weight 		#parameters  258048
# weight n° 190 	layer: Mixed_6e.branch7x7_3.bn.weight 		#parameters  192
# weight n° 191 	layer: Mixed_6e.branch7x7_3.bn.bias 		#parameters  192
# weight n° 192 	layer: Mixed_6e.branch7x7dbl_1.conv.weight 		#parameters  147456
# weight n° 193 	layer: Mixed_6e.branch7x7dbl_1.bn.weight 		#parameters  192
# weight n° 194 	layer: Mixed_6e.branch7x7dbl_1.bn.bias 		#parameters  192
# weight n° 195 	layer: Mixed_6e.branch7x7dbl_2.conv.weight 		#parameters  258048
# weight n° 196 	layer: Mixed_6e.branch7x7dbl_2.bn.weight 		#parameters  192
# weight n° 197 	layer: Mixed_6e.branch7x7dbl_2.bn.bias 		#parameters  192
# weight n° 198 	layer: Mixed_6e.branch7x7dbl_3.conv.weight 		#parameters  258048
# weight n° 199 	layer: Mixed_6e.branch7x7dbl_3.bn.weight 		#parameters  192
# weight n° 200 	layer: Mixed_6e.branch7x7dbl_3.bn.bias 		#parameters  192
# weight n° 201 	layer: Mixed_6e.branch7x7dbl_4.conv.weight 		#parameters  258048
# weight n° 202 	layer: Mixed_6e.branch7x7dbl_4.bn.weight 		#parameters  192
# weight n° 203 	layer: Mixed_6e.branch7x7dbl_4.bn.bias 		#parameters  192
# weight n° 204 	layer: Mixed_6e.branch7x7dbl_5.conv.weight 		#parameters  258048
# weight n° 205 	layer: Mixed_6e.branch7x7dbl_5.bn.weight 		#parameters  192
# weight n° 206 	layer: Mixed_6e.branch7x7dbl_5.bn.bias 		#parameters  192
# weight n° 207 	layer: Mixed_6e.branch_pool.conv.weight 		#parameters  147456
# weight n° 208 	layer: Mixed_6e.branch_pool.bn.weight 		#parameters  192
# weight n° 209 	layer: Mixed_6e.branch_pool.bn.bias 		#parameters  192
# weight n° 210 	layer: AuxLogits.conv0.conv.weight 		#parameters  98304
# weight n° 211 	layer: AuxLogits.conv0.bn.weight 		#parameters  128
# weight n° 212 	layer: AuxLogits.conv0.bn.bias 		#parameters  128
# weight n° 213 	layer: AuxLogits.conv1.conv.weight 		#parameters  2457600
# weight n° 214 	layer: AuxLogits.conv1.bn.weight 		#parameters  768
# weight n° 215 	layer: AuxLogits.conv1.bn.bias 		#parameters  768
# weight n° 216 	layer: AuxLogits.fc.weight 		#parameters  2304
# weight n° 217 	layer: AuxLogits.fc.bias 		#parameters  3
# weight n° 218 	layer: Mixed_7a.branch3x3_1.conv.weight 		#parameters  147456
# weight n° 219 	layer: Mixed_7a.branch3x3_1.bn.weight 		#parameters  192
# weight n° 220 	layer: Mixed_7a.branch3x3_1.bn.bias 		#parameters  192
# weight n° 221 	layer: Mixed_7a.branch3x3_2.conv.weight 		#parameters  552960
# weight n° 222 	layer: Mixed_7a.branch3x3_2.bn.weight 		#parameters  320
# weight n° 223 	layer: Mixed_7a.branch3x3_2.bn.bias 		#parameters  320
# weight n° 224 	layer: Mixed_7a.branch7x7x3_1.conv.weight 		#parameters  147456
# weight n° 225 	layer: Mixed_7a.branch7x7x3_1.bn.weight 		#parameters  192
# weight n° 226 	layer: Mixed_7a.branch7x7x3_1.bn.bias 		#parameters  192
# weight n° 227 	layer: Mixed_7a.branch7x7x3_2.conv.weight 		#parameters  258048
# weight n° 228 	layer: Mixed_7a.branch7x7x3_2.bn.weight 		#parameters  192
# weight n° 229 	layer: Mixed_7a.branch7x7x3_2.bn.bias 		#parameters  192
# weight n° 230 	layer: Mixed_7a.branch7x7x3_3.conv.weight 		#parameters  258048
# weight n° 231 	layer: Mixed_7a.branch7x7x3_3.bn.weight 		#parameters  192
# weight n° 232 	layer: Mixed_7a.branch7x7x3_3.bn.bias 		#parameters  192
# weight n° 233 	layer: Mixed_7a.branch7x7x3_4.conv.weight 		#parameters  331776
# weight n° 234 	layer: Mixed_7a.branch7x7x3_4.bn.weight 		#parameters  192
# weight n° 235 	layer: Mixed_7a.branch7x7x3_4.bn.bias 		#parameters  192
# weight n° 236 	layer: Mixed_7b.branch1x1.conv.weight 		#parameters  409600
# weight n° 237 	layer: Mixed_7b.branch1x1.bn.weight 		#parameters  320
# weight n° 238 	layer: Mixed_7b.branch1x1.bn.bias 		#parameters  320
# weight n° 239 	layer: Mixed_7b.branch3x3_1.conv.weight 		#parameters  491520
# weight n° 240 	layer: Mixed_7b.branch3x3_1.bn.weight 		#parameters  384
# weight n° 241 	layer: Mixed_7b.branch3x3_1.bn.bias 		#parameters  384
# weight n° 242 	layer: Mixed_7b.branch3x3_2a.conv.weight 		#parameters  442368
# weight n° 243 	layer: Mixed_7b.branch3x3_2a.bn.weight 		#parameters  384
# weight n° 244 	layer: Mixed_7b.branch3x3_2a.bn.bias 		#parameters  384
# weight n° 245 	layer: Mixed_7b.branch3x3_2b.conv.weight 		#parameters  442368
# weight n° 246 	layer: Mixed_7b.branch3x3_2b.bn.weight 		#parameters  384
# weight n° 247 	layer: Mixed_7b.branch3x3_2b.bn.bias 		#parameters  384
# weight n° 248 	layer: Mixed_7b.branch3x3dbl_1.conv.weight 		#parameters  573440
# weight n° 249 	layer: Mixed_7b.branch3x3dbl_1.bn.weight 		#parameters  448
# weight n° 250 	layer: Mixed_7b.branch3x3dbl_1.bn.bias 		#parameters  448
# weight n° 251 	layer: Mixed_7b.branch3x3dbl_2.conv.weight 		#parameters  1548288
# weight n° 252 	layer: Mixed_7b.branch3x3dbl_2.bn.weight 		#parameters  384
# weight n° 253 	layer: Mixed_7b.branch3x3dbl_2.bn.bias 		#parameters  384
# weight n° 254 	layer: Mixed_7b.branch3x3dbl_3a.conv.weight 		#parameters  442368
# weight n° 255 	layer: Mixed_7b.branch3x3dbl_3a.bn.weight 		#parameters  384
# weight n° 256 	layer: Mixed_7b.branch3x3dbl_3a.bn.bias 		#parameters  384
# weight n° 257 	layer: Mixed_7b.branch3x3dbl_3b.conv.weight 		#parameters  442368
# weight n° 258 	layer: Mixed_7b.branch3x3dbl_3b.bn.weight 		#parameters  384
# weight n° 259 	layer: Mixed_7b.branch3x3dbl_3b.bn.bias 		#parameters  384
# weight n° 260 	layer: Mixed_7b.branch_pool.conv.weight 		#parameters  245760
# weight n° 261 	layer: Mixed_7b.branch_pool.bn.weight 		#parameters  192
# weight n° 262 	layer: Mixed_7b.branch_pool.bn.bias 		#parameters  192
# weight n° 263 	layer: Mixed_7c.branch1x1.conv.weight 		#parameters  655360
# weight n° 264 	layer: Mixed_7c.branch1x1.bn.weight 		#parameters  320
# weight n° 265 	layer: Mixed_7c.branch1x1.bn.bias 		#parameters  320
# weight n° 266 	layer: Mixed_7c.branch3x3_1.conv.weight 		#parameters  786432
# weight n° 267 	layer: Mixed_7c.branch3x3_1.bn.weight 		#parameters  384
# weight n° 268 	layer: Mixed_7c.branch3x3_1.bn.bias 		#parameters  384
# weight n° 269 	layer: Mixed_7c.branch3x3_2a.conv.weight 		#parameters  442368
# weight n° 270 	layer: Mixed_7c.branch3x3_2a.bn.weight 		#parameters  384
# weight n° 271 	layer: Mixed_7c.branch3x3_2a.bn.bias 		#parameters  384
# weight n° 272 	layer: Mixed_7c.branch3x3_2b.conv.weight 		#parameters  442368
# weight n° 273 	layer: Mixed_7c.branch3x3_2b.bn.weight 		#parameters  384
# weight n° 274 	layer: Mixed_7c.branch3x3_2b.bn.bias 		#parameters  384
# weight n° 275 	layer: Mixed_7c.branch3x3dbl_1.conv.weight 		#parameters  917504
# weight n° 276 	layer: Mixed_7c.branch3x3dbl_1.bn.weight 		#parameters  448
# weight n° 277 	layer: Mixed_7c.branch3x3dbl_1.bn.bias 		#parameters  448
# weight n° 278 	layer: Mixed_7c.branch3x3dbl_2.conv.weight 		#parameters  1548288
# weight n° 279 	layer: Mixed_7c.branch3x3dbl_2.bn.weight 		#parameters  384
# weight n° 280 	layer: Mixed_7c.branch3x3dbl_2.bn.bias 		#parameters  384
# weight n° 281 	layer: Mixed_7c.branch3x3dbl_3a.conv.weight 		#parameters  442368
# weight n° 282 	layer: Mixed_7c.branch3x3dbl_3a.bn.weight 		#parameters  384
# weight n° 283 	layer: Mixed_7c.branch3x3dbl_3a.bn.bias 		#parameters  384
# weight n° 284 	layer: Mixed_7c.branch3x3dbl_3b.conv.weight 		#parameters  442368
# weight n° 285 	layer: Mixed_7c.branch3x3dbl_3b.bn.weight 		#parameters  384
# weight n° 286 	layer: Mixed_7c.branch3x3dbl_3b.bn.bias 		#parameters  384
# weight n° 287 	layer: Mixed_7c.branch_pool.conv.weight 		#parameters  393216
# weight n° 288 	layer: Mixed_7c.branch_pool.conv.bias 		#parameters  192
# weight n° 289 	layer: Mixed_7c.branch_pool.bn.weight 		#parameters  192
# weight n° 290 	layer: Mixed_7c.branch_pool.bn.bias 		#parameters  192
# weight n° 291 	layer: fc.fc1.weight 		#parameters  1048576
# weight n° 292 	layer: fc.fc1.bias 		#parameters  512
# weight n° 293 	layer: fc.fc2.weight 		#parameters  1536
# weight n° 294 	layer: fc.fc2.bias 		#parameters  3
#
# Total Trainable Params: 25396390

# %%
for module, layer in model_inception.named_modules():
    parse_module = module.split('.')
    sub_level=True
    if len(parse_module)==1:
        if sub_level:
            print(module, end='')
            sub_level=False
        else:
            print()
            print(module)
            #sub_level=True
    
    if len(parse_module)==2:
        if parse_module[1]=='conv':
            print('...', parse_module[1], '> ', end='')
        elif parse_module[1]=='bn':
            print(parse_module[1])
            sub_level=False
        elif sub_level:
            print('...', parse_module[1], end='')
            sub_level=False
        else:
            print()
            print('...', parse_module[1])
            sub_level = True
                
    if len(parse_module)==3:
        if parse_module[2]=='conv':
            print('...', parse_module[2], '> ', end='')
        elif parse_module[2]=='bn':
            print(parse_module[2])
            sub_level=False
        else:
            print('...........', parse_module[2])
# Out:
# Conv2d_1a_3x3... conv > bn
# Conv2d_2a_3x3... conv > bn
# Conv2d_2b_3x3... conv > bn
# maxpool1Conv2d_3b_1x1... conv > bn
# Conv2d_4a_3x3... conv > bn
# maxpool2Mixed_5b... branch1x1  conv  > bn
# ... branch5x5_1  conv  > bn
# ... branch5x5_2  conv  > bn
# ... branch3x3dbl_1  conv  > bn
# ... branch3x3dbl_2  conv  > bn
# ... branch3x3dbl_3  conv  > bn
# ... branch_pool  conv  > bn
# Mixed_5c... branch1x1  conv  > bn
# ... branch5x5_1  conv  > bn
# ... branch5x5_2  conv  > bn
# ... branch3x3dbl_1  conv  > bn
# ... branch3x3dbl_2  conv  > bn
# ... branch3x3dbl_3  conv  > bn
# ... branch_pool  conv  > bn
# Mixed_5d... branch1x1  conv  > bn
# ... branch5x5_1  conv  > bn
# ... branch5x5_2  conv  > bn
# ... branch3x3dbl_1  conv  > bn
# ... branch3x3dbl_2  conv  > bn
# ... branch3x3dbl_3  conv  > bn
# ... branch_pool  conv  > bn
# Mixed_6a... branch3x3  conv  > bn
# ... branch3x3dbl_1  conv  > bn
# ... branch3x3dbl_2  conv  > bn
# ... branch3x3dbl_3  conv  > bn
# Mixed_6b... branch1x1  conv  > bn
# ... branch7x7_1  conv  > bn
# ... branch7x7_2  conv  > bn
# ... branch7x7_3  conv  > bn
# ... branch7x7dbl_1  conv  > bn
# ... branch7x7dbl_2  conv  > bn
# ... branch7x7dbl_3  conv  > bn
# ... branch7x7dbl_4  conv  > bn
# ... branch7x7dbl_5  conv  > bn
# ... branch_pool  conv  > bn
# Mixed_6c... branch1x1  conv  > bn
# ... branch7x7_1  conv  > bn
# ... branch7x7_2  conv  > bn
# ... branch7x7_3  conv  > bn
# ... branch7x7dbl_1  conv  > bn
# ... branch7x7dbl_2  conv  > bn
# ... branch7x7dbl_3  conv  > bn
# ... branch7x7dbl_4  conv  > bn
# ... branch7x7dbl_5  conv  > bn
# ... branch_pool  conv  > bn
# Mixed_6d... branch1x1  conv  > bn
# ... branch7x7_1  conv  > bn
# ... branch7x7_2  conv  > bn
# ... branch7x7_3  conv  > bn
# ... branch7x7dbl_1  conv  > bn
# ... branch7x7dbl_2  conv  > bn
# ... branch7x7dbl_3  conv  > bn
# ... branch7x7dbl_4  conv  > bn
# ... branch7x7dbl_5  conv  > bn
# ... branch_pool  conv  > bn
# Mixed_6e... branch1x1  conv  > bn
# ... branch7x7_1  conv  > bn
# ... branch7x7_2  conv  > bn
# ... branch7x7_3  conv  > bn
# ... branch7x7dbl_1  conv  > bn
# ... branch7x7dbl_2  conv  > bn
# ... branch7x7dbl_3  conv  > bn
# ... branch7x7dbl_4  conv  > bn
# ... branch7x7dbl_5  conv  > bn
# ... branch_pool  conv  > bn
# AuxLogits... conv0  conv  > bn
# ... conv1  conv  > bn
# ... fcMixed_7a... branch3x3_1  conv  > bn
# ... branch3x3_2  conv  > bn
# ... branch7x7x3_1  conv  > bn
# ... branch7x7x3_2  conv  > bn
# ... branch7x7x3_3  conv  > bn
# ... branch7x7x3_4  conv  > bn
# Mixed_7b... branch1x1  conv  > bn
# ... branch3x3_1  conv  > bn
# ... branch3x3_2a  conv  > bn
# ... branch3x3_2b  conv  > bn
# ... branch3x3dbl_1  conv  > bn
# ... branch3x3dbl_2  conv  > bn
# ... branch3x3dbl_3a  conv  > bn
# ... branch3x3dbl_3b  conv  > bn
# ... branch_pool  conv  > bn
# Mixed_7c... branch1x1  conv  > bn
# ... branch3x3_1  conv  > bn
# ... branch3x3_2a  conv  > bn
# ... branch3x3_2b  conv  > bn
# ... branch3x3dbl_1  conv  > bn
# ... branch3x3dbl_2  conv  > bn
# ... branch3x3dbl_3a  conv  > bn
# ... branch3x3dbl_3b  conv  > bn
# ... branch_pool  conv  > bn
# avgpooldropoutfc... fc1... relu... drop... fc2

# %%
# Instantiate dataloaders
image_size = (299,299)  # max(450,576)
num_workers = 1
batch_size_train = 64
batch_size_val = 10
batch_size_test = 10
loaders=get_loaders(image_size, batch_size_train, batch_size_val, batch_size_test, num_workers)

# %%
dataiter = iter(loaders['train'])
images, true_labels = dataiter.next()
print(images.shape, true_labels.shape)
# Out:
# torch.Size([64, 3, 299, 299]) torch.Size([64])

# %%
# Define training parameters
criterion = nn.CrossEntropyLoss()
#criterion = nn.CrossEntropyLoss(weight=class_weights)        
params_to_update = [{'params': model_inception.Mixed_7c.branch_pool.parameters()}, {'params': model_inception.AuxLogits.fc.parameters()}, {'params': model_inception.fc.parameters()}] 
optimizer = optim.Adam(params_to_update, lr=0.000001, betas=(0.9,0.999))
#optimizer = optim.RMSprop(params_to_update, lr=0.0001)
#scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.66)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=2)

# %%
# train the model
n_epochs = 4
print_every = 57
save_path = './models'

model_inception, train_loss, val_loss = train(n_epochs, loaders, model_inception, optimizer, criterion, use_cuda, 'model_inception_fine.pt', is_inception=True)
# Out:
# Epoch [1/4] Step [57/57]	 Loss: 1.5856	 avg_Loss: 1.5561	 exec_time: 418 s	 train_time:	 0 h 6 m
# Epoch [1/4]	 avg_train Loss: 1.5561			 avg_validation Loss: 1.0892	 val_accuracy: 42.00
# improved model saved to disk
# Epoch [2/4] Step [57/57]	 Loss: 1.5499	 avg_Loss: 1.5429	 exec_time: 421 s	 train_time:	 0 h 14 m
# Epoch [2/4]	 avg_train Loss: 1.5429			 avg_validation Loss: 1.0908	 val_accuracy: 42.00
# Epoch [3/4] Step [57/57]	 Loss: 1.5231	 avg_Loss: 1.5383	 exec_time: 421 s	 train_time:	 0 h 22 m
# Epoch [3/4]	 avg_train Loss: 1.5383			 avg_validation Loss: 1.0913	 val_accuracy: 42.00
# Epoch [4/4] Step [57/57]	 Loss: 1.4893	 avg_Loss: 1.5324	 exec_time: 420 s	 train_time:	 0 h 29 m
# Epoch [4/4]	 avg_train Loss: 1.5324			 avg_validation Loss: 1.0930	 val_accuracy: 42.00

# %%
# Display loss reduction profile
plot_loss('Inception_V3', train_loss, val_loss)

# %%
# load the model that got the best validation accuracy
if torch.cuda.is_available():
    model_inception.load_state_dict(torch.load('models/model_inception.pt'))
else:
    model_inception.load_state_dict(torch.load('models/model_inception.pt', map_location=torch.device('cpu')))

# %%
with torch.no_grad():
    test(loaders, model_inception, criterion, use_cuda)

get_scores(model_inception, (450,576))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=60.0), HTML(value='')))
# Test Loss: 0.819266
#
# Test Accuracy of melanoma:  33%     (39/117)
# Test Accuracy of nevus:  84%     (329/393)
# Test Accuracy of seborrheic_keratosis:  24%     (22/90)
#
# Test Accuracy (Overall):                                                65%     (390/600)
#
# getting predictions on all test images:
# HBox(children=(FloatProgress(value=0.0, max=600.0), HTML(value='')))
# writing score csv file
# Category 1 Score: 0.693
# Category 2 Score: 0.883
# Category 3 Score: 0.788

# %%
num_classes = 3
model_inception = models.inception_v3(pretrained=True, aux_logits=True)             # Be careful, InceptionV3 expects (299,299) sized images and has auxiliary output
model_inception = model_inception.to(device)

for param in model_inception.parameters():               # freeze feature parameters of pre-trained model
    param.requires_grad = True

model_inception.AuxLogits.fc = nn.Linear(768, num_classes)

#BasicConv2d = nn.Sequential(OrderedDict([('conv', nn.Conv2d(2048, 192, kernel_size=(1,1), stride=(1,1))),
#                                         ('bn', nn.BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True))]))

classifier = nn.Sequential(OrderedDict([ ('fc1', nn.Linear(2048, 1024)),     
                                         ('relu', nn.ReLU()),
                                        ('drop', nn.Dropout(0.1)),
                                         ('fc2', nn.Linear(1024, num_classes)) 
                                         ]))                                                # ('output', nn.Softmax(dim=1))

#model_inception.Mixed_7c.branch_pool = BasicConv2d
model_inception.fc = classifier

print(summary(model_inception.to(device), torch.zeros((1, 3, 299, 299)).to(device), show_input=False, show_hierarchical=False, print_summary=False))
# Out:
# Downloading: "https://download.pytorch.org/models/inception_v3_google-1a9a5a14.pth" to /root/.cache/torch/hub/checkpoints/inception_v3_google-1a9a5a14.pth
# HBox(children=(FloatProgress(value=0.0, max=108857766.0), HTML(value='')))
# ------------------------------------------------------------------------------
#            Layer (type)          Output Shape         Param #     Tr. Param #
# ==============================================================================
#           BasicConv2d-1     [1, 32, 149, 149]             928             928
#           BasicConv2d-2     [1, 32, 147, 147]           9,280           9,280
#           BasicConv2d-3     [1, 64, 147, 147]          18,560          18,560
#             MaxPool2d-4       [1, 64, 73, 73]               0               0
#           BasicConv2d-5       [1, 80, 73, 73]           5,280           5,280
#           BasicConv2d-6      [1, 192, 71, 71]         138,624         138,624
#             MaxPool2d-7      [1, 192, 35, 35]               0               0
#            InceptionA-8      [1, 256, 35, 35]         255,904         255,904
#            InceptionA-9      [1, 288, 35, 35]         277,472         277,472
#           InceptionA-10      [1, 288, 35, 35]         285,152         285,152
#           InceptionB-11      [1, 768, 17, 17]       1,153,280       1,153,280
#           InceptionC-12      [1, 768, 17, 17]       1,297,408       1,297,408
#           InceptionC-13      [1, 768, 17, 17]       1,691,008       1,691,008
#           InceptionC-14      [1, 768, 17, 17]       1,691,008       1,691,008
#           InceptionC-15      [1, 768, 17, 17]       2,141,952       2,141,952
#           InceptionD-16       [1, 1280, 8, 8]       1,698,304       1,698,304
#           InceptionE-17       [1, 2048, 8, 8]       5,044,608       5,044,608
#           InceptionE-18       [1, 2048, 8, 8]       6,076,800       6,076,800
#    AdaptiveAvgPool2d-19       [1, 2048, 1, 1]               0               0
#              Dropout-20       [1, 2048, 1, 1]               0               0
#               Linear-21             [1, 1024]       2,098,176       2,098,176
#                 ReLU-22             [1, 1024]               0               0
#              Dropout-23             [1, 1024]               0               0
#               Linear-24                [1, 3]           3,075           3,075
# ==============================================================================
# Total params: 23,886,819
# Trainable params: 23,886,819
# Non-trainable params: 0
# ------------------------------------------------------------------------------

# %%
# Instantiate dataloaders
image_size = (299,299)  # max(450,576)
num_workers = 1
batch_size_train = 32
batch_size_val = 10
batch_size_test = 10
loaders=get_loaders(image_size, batch_size_train, batch_size_val, batch_size_test, num_workers)

# %%
# Define training parameters
criterion = nn.CrossEntropyLoss()
#criterion = nn.CrossEntropyLoss(weight=class_weights)        
params_to_update = [{'params': model_inception.parameters()}] 
optimizer = optim.Adam(params_to_update, lr=0.0001, betas=(0.9,0.999))
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=2)

# %%
# train the model
n_epochs = 15
print_every = 127
save_path = './models'

model_inception, train_loss, val_loss = train(n_epochs, loaders, model_inception, optimizer, criterion, use_cuda, 'model_inception_3.pt', is_inception=True)
# Out:
# Epoch [1/15] Step [127/127]	 Loss: 1.8778	 avg_Loss: 0.9341	 exec_time: 2188 s	 train_time:	 0 h 36 m
# Epoch [1/15]	 avg_train Loss: 0.9341			 avg_validation Loss: 0.5783	 val_accuracy: 72.67
# improved model saved to disk
# Epoch [2/15] Step [127/127]	 Loss: 0.2858	 avg_Loss: 0.6348	 exec_time: 1706 s	 train_time:	 1 h 7 m
# Epoch [2/15]	 avg_train Loss: 0.6348			 avg_validation Loss: 0.4782	 val_accuracy: 79.33
# improved model saved to disk
# Epoch [3/15] Step [127/127]	 Loss: 0.5007	 avg_Loss: 0.4938	 exec_time: 1748 s	 train_time:	 1 h 38 m
# Epoch [3/15]	 avg_train Loss: 0.4938			 avg_validation Loss: 0.5082	 val_accuracy: 78.00
# Epoch [4/15] Step [127/127]	 Loss: 1.9190	 avg_Loss: 0.4281	 exec_time: 1723 s	 train_time:	 2 h 8 m
# Epoch [4/15]	 avg_train Loss: 0.4281			 avg_validation Loss: 0.4386	 val_accuracy: 79.33
# improved model saved to disk
# Epoch [5/15] Step [127/127]	 Loss: 0.0548	 avg_Loss: 0.3772	 exec_time: 1755 s	 train_time:	 2 h 39 m
# Epoch [5/15]	 avg_train Loss: 0.3772			 avg_validation Loss: 0.3494	 val_accuracy: 86.67
# improved model saved to disk
# Epoch [6/15] Step [127/127]	 Loss: 5.6204	 avg_Loss: 0.3108	 exec_time: 1736 s	 train_time:	 3 h 10 m
# Epoch [6/15]	 avg_train Loss: 0.3108			 avg_validation Loss: 0.4559	 val_accuracy: 81.33
# Epoch [7/15] Step [127/127]	 Loss: 1.1546	 avg_Loss: 0.3199	 exec_time: 1752 s	 train_time:	 3 h 41 m
# Epoch [7/15]	 avg_train Loss: 0.3199			 avg_validation Loss: 0.5275	 val_accuracy: 84.00
# Epoch [8/15] Step [127/127]	 Loss: 1.0664	 avg_Loss: 0.2713	 exec_time: 1744 s	 train_time:	 4 h 11 m
# Epoch [8/15]	 avg_train Loss: 0.2713			 avg_validation Loss: 0.2614	 val_accuracy: 88.67
# improved model saved to disk
# Epoch [9/15] Step [127/127]	 Loss: 2.1335	 avg_Loss: 0.2372	 exec_time: 1598 s	 train_time:	 4 h 40 m
# Epoch [9/15]	 avg_train Loss: 0.2372			 avg_validation Loss: 0.3603	 val_accuracy: 89.33
# Epoch [10/15] Step [127/127]	 Loss: 0.1122	 avg_Loss: 0.2016	 exec_time: 1511 s	 train_time:	 5 h 7 m
# Epoch [10/15]	 avg_train Loss: 0.2016			 avg_validation Loss: 0.3484	 val_accuracy: 84.67
# Epoch [11/15] Step [127/127]	 Loss: 0.0052	 avg_Loss: 0.1830	 exec_time: 1596 s	 train_time:	 5 h 35 m
# Epoch [11/15]	 avg_train Loss: 0.1830			 avg_validation Loss: 0.3257	 val_accuracy: 87.33
# Epoch [12/15] Step [127/127]	 Loss: 0.7253	 avg_Loss: 0.1135	 exec_time: 1591 s	 train_time:	 6 h 3 m
# Epoch [12/15]	 avg_train Loss: 0.1135			 avg_validation Loss: 0.4293	 val_accuracy: 86.67
# Epoch [13/15] Step [127/127]	 Loss: 3.4796	 avg_Loss: 0.0982	 exec_time: 1541 s	 train_time:	 6 h 30 m
# Epoch [13/15]	 avg_train Loss: 0.0982			 avg_validation Loss: 0.4626	 val_accuracy: 88.00
# Epoch [14/15] Step [127/127]	 Loss: 4.1763	 avg_Loss: 0.1171	 exec_time: 1514 s	 train_time:	 6 h 57 m
# Epoch [14/15]	 avg_train Loss: 0.1171			 avg_validation Loss: 0.3224	 val_accuracy: 92.00
# Epoch [15/15] Step [127/127]	 Loss: 0.1962	 avg_Loss: 0.0733	 exec_time: 1555 s	 train_time:	 7 h 24 m
# Epoch [15/15]	 avg_train Loss: 0.0733			 avg_validation Loss: 0.2984	 val_accuracy: 91.33

# %%
# Display loss reduction profile
plot_loss('Inception_V3', train_loss, val_loss)

# %%
# load the model that got the best validation accuracy
if torch.cuda.is_available():
    model_inception.load_state_dict(torch.load('models/model_inception_3.pt'))
else:
    model_inception.load_state_dict(torch.load('models/model_inception_3.pt', map_location=torch.device('cpu')))

# %%
with torch.no_grad():
    test(loaders, model_inception, criterion, use_cuda)
    get_scores(model_inception, (450,576))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=60.0), HTML(value='')))
# Test Loss: 0.503513
#
# Test Accuracy of melanoma:  95%     (111/117)
# Test Accuracy of nevus:  80%     (314/393)
# Test Accuracy of seborrheic_keratosis:  100%    (90/90)
#
# Test Accuracy (Overall):                                                86%     (515/600)
#
# getting predictions on all test images:
# HBox(children=(FloatProgress(value=0.0, max=600.0), HTML(value='')))
# writing score csv file
# Category 1 Score: 0.843
# Category 2 Score: 0.934
# Category 3 Score: 0.888

# %% [markdown]
# # Testing with ResNet152 pre-trained model

# %%
model_Resnet= models.resnet152(pretrained = True)

for param in model_Resnet.parameters():
    param.requires_grad = False
    
from collections import OrderedDict
classifier = nn.Sequential(OrderedDict([
                          ('Dropout-1',nn.Dropout(0.4)),
                          ('fc1', nn.Linear(2048, 3)),
                          ]))

model_Resnet.fc = classifier

if use_cuda:
    model_Resnet = model_Resnet.cuda()

print(summary(model_Resnet.to(device), torch.zeros((1, 3, 224, 224)).to(device), show_input=False, show_hierarchical=False, print_summary=False))
# Out:
# ------------------------------------------------------------------------------
#            Layer (type)          Output Shape         Param #     Tr. Param #
# ==============================================================================
#                Conv2d-1     [1, 64, 112, 112]           9,408               0
#           BatchNorm2d-2     [1, 64, 112, 112]             128               0
#                  ReLU-3     [1, 64, 112, 112]               0               0
#             MaxPool2d-4       [1, 64, 56, 56]               0               0
#            Bottleneck-5      [1, 256, 56, 56]          75,008               0
#            Bottleneck-6      [1, 256, 56, 56]          70,400               0
#            Bottleneck-7      [1, 256, 56, 56]          70,400               0
#            Bottleneck-8      [1, 512, 28, 28]         379,392               0
#            Bottleneck-9      [1, 512, 28, 28]         280,064               0
#           Bottleneck-10      [1, 512, 28, 28]         280,064               0
#           Bottleneck-11      [1, 512, 28, 28]         280,064               0
#           Bottleneck-12      [1, 512, 28, 28]         280,064               0
#           Bottleneck-13      [1, 512, 28, 28]         280,064               0
#           Bottleneck-14      [1, 512, 28, 28]         280,064               0
#           Bottleneck-15      [1, 512, 28, 28]         280,064               0
#           Bottleneck-16     [1, 1024, 14, 14]       1,512,448               0
#           Bottleneck-17     [1, 1024, 14, 14]       1,117,184               0
#           Bottleneck-18     [1, 1024, 14, 14]       1,117,184               0
#           Bottleneck-19     [1, 1024, 14, 14]       1,117,184               0
#           Bottleneck-20     [1, 1024, 14, 14]       1,117,184               0
#           Bottleneck-21     [1, 1024, 14, 14]       1,117,184               0
#           Bottleneck-22     [1, 1024, 14, 14]       1,117,184               0
#           Bottleneck-23     [1, 1024, 14, 14]       1,117,184               0
#           Bottleneck-24     [1, 1024, 14, 14]       1,117,184               0
#           Bottleneck-25     [1, 1024, 14, 14]       1,117,184               0
#           Bottleneck-26     [1, 1024, 14, 14]       1,117,184               0
#           Bottleneck-27     [1, 1024, 14, 14]       1,117,184               0
#           Bottleneck-28     [1, 1024, 14, 14]       1,117,184               0
#           Bottleneck-29     [1, 1024, 14, 14]       1,117,184               0
#           Bottleneck-30     [1, 1024, 14, 14]       1,117,184               0
#           Bottleneck-31     [1, 1024, 14, 14]       1,117,184               0
#           Bottleneck-32     [1, 1024, 14, 14]       1,117,184               0
#           Bottleneck-33     [1, 1024, 14, 14]       1,117,184               0
#           Bottleneck-34     [1, 1024, 14, 14]       1,117,184               0
#           Bottleneck-35     [1, 1024, 14, 14]       1,117,184               0
#           Bottleneck-36     [1, 1024, 14, 14]       1,117,184               0
#           Bottleneck-37     [1, 1024, 14, 14]       1,117,184               0
#           Bottleneck-38     [1, 1024, 14, 14]       1,117,184               0
#           Bottleneck-39     [1, 1024, 14, 14]       1,117,184               0
#           Bottleneck-40     [1, 1024, 14, 14]       1,117,184               0
#           Bottleneck-41     [1, 1024, 14, 14]       1,117,184               0
#           Bottleneck-42     [1, 1024, 14, 14]       1,117,184               0
#           Bottleneck-43     [1, 1024, 14, 14]       1,117,184               0
#           Bottleneck-44     [1, 1024, 14, 14]       1,117,184               0
#           Bottleneck-45     [1, 1024, 14, 14]       1,117,184               0
#           Bottleneck-46     [1, 1024, 14, 14]       1,117,184               0
#           Bottleneck-47     [1, 1024, 14, 14]       1,117,184               0
#           Bottleneck-48     [1, 1024, 14, 14]       1,117,184               0
#           Bottleneck-49     [1, 1024, 14, 14]       1,117,184               0
#           Bottleneck-50     [1, 1024, 14, 14]       1,117,184               0
#           Bottleneck-51     [1, 1024, 14, 14]       1,117,184               0
#           Bottleneck-52       [1, 2048, 7, 7]       6,039,552               0
#           Bottleneck-53       [1, 2048, 7, 7]       4,462,592               0
#           Bottleneck-54       [1, 2048, 7, 7]       4,462,592               0
#    AdaptiveAvgPool2d-55       [1, 2048, 1, 1]               0               0
#              Dropout-56             [1, 2048]               0               0
#               Linear-57                [1, 3]           6,147           6,147
# ==============================================================================
# Total params: 58,149,955
# Trainable params: 6,147
# Non-trainable params: 58,143,808
# ------------------------------------------------------------------------------

# %%
# Set up dataloaders
num_classes = 3
image_size = (224,224)  # max(450,576)
num_workers = 1
batch_size_train = 10
batch_size_val = 10
batch_size_test = 10
loaders=get_loaders(image_size, batch_size_train, batch_size_val, batch_size_test, num_workers)

# Define parameters
criterion = nn.CrossEntropyLoss()
#optimizer = optim.Adam(model_Resnet.fc.parameters(), lr=0.0001)
optimizer = optim.SGD(model_Resnet.fc.parameters(), lr = 0.001, momentum = 0.91)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=2)

# Train model
n_epochs = 15
print_every = 368
save_path = './models'
model_Resnet, train_loss, val_loss = train(n_epochs, loaders, model_Resnet, optimizer, criterion, use_cuda,
                                           'model_Resnet.pt', is_inception=False)

# Display loss reduction profile
plot_loss('ResNet_152', train_loss, val_loss)
# Out:
# Epoch [1/15] Step [368/368]	 Loss: 0.7945	 avg_Loss: 0.9627	 exec_time: 407 s	 train_time:	 0 h 6 m
# Epoch [1/15]	 avg_train Loss: 0.9627			 avg_validation Loss: 0.7985	 accuracy: 61.33
# improved model saved to disk
# Epoch [2/15] Step [368/368]	 Loss: 1.1981	 avg_Loss: 0.8977	 exec_time: 410 s	 train_time:	 0 h 14 m
# Epoch [2/15]	 avg_train Loss: 0.8977			 avg_validation Loss: 0.9903	 accuracy: 52.67
# Epoch [3/15] Step [368/368]	 Loss: 0.8191	 avg_Loss: 0.8387	 exec_time: 411 s	 train_time:	 0 h 21 m
# Epoch [3/15]	 avg_train Loss: 0.8387			 avg_validation Loss: 0.7132	 accuracy: 71.33
# improved model saved to disk
# Epoch [4/15] Step [368/368]	 Loss: 0.3165	 avg_Loss: 0.8659	 exec_time: 412 s	 train_time:	 0 h 28 m
# Epoch [4/15]	 avg_train Loss: 0.8659			 avg_validation Loss: 0.7785	 accuracy: 72.67
# Epoch [5/15] Step [368/368]	 Loss: 0.8709	 avg_Loss: 0.8892	 exec_time: 413 s	 train_time:	 0 h 36 m
# Epoch [5/15]	 avg_train Loss: 0.8892			 avg_validation Loss: 0.7925	 accuracy: 67.33
# Epoch [6/15] Step [368/368]	 Loss: 0.5048	 avg_Loss: 0.8981	 exec_time: 414 s	 train_time:	 0 h 43 m
# Epoch [6/15]	 avg_train Loss: 0.8981			 avg_validation Loss: 0.7571	 accuracy: 72.00
# Epoch [7/15] Step [368/368]	 Loss: 0.5064	 avg_Loss: 0.8346	 exec_time: 414 s	 train_time:	 0 h 50 m
# Epoch [7/15]	 avg_train Loss: 0.8346			 avg_validation Loss: 0.8187	 accuracy: 62.67
# Epoch [8/15] Step [368/368]	 Loss: 0.9769	 avg_Loss: 0.8396	 exec_time: 414 s	 train_time:	 0 h 58 m
# Epoch [8/15]	 avg_train Loss: 0.8396			 avg_validation Loss: 0.7144	 accuracy: 74.00
# Epoch [9/15] Step [368/368]	 Loss: 0.9856	 avg_Loss: 0.8110	 exec_time: 414 s	 train_time:	 1 h 5 m
# Epoch [9/15]	 avg_train Loss: 0.8110			 avg_validation Loss: 0.6794	 accuracy: 71.33
# improved model saved to disk
# Epoch [10/15] Step [368/368]	 Loss: 1.2439	 avg_Loss: 0.7986	 exec_time: 414 s	 train_time:	 1 h 13 m
# Epoch [10/15]	 avg_train Loss: 0.7986			 avg_validation Loss: 0.6970	 accuracy: 71.33
# Epoch [11/15] Step [368/368]	 Loss: 0.4187	 avg_Loss: 0.7829	 exec_time: 413 s	 train_time:	 1 h 20 m
# Epoch [11/15]	 avg_train Loss: 0.7829			 avg_validation Loss: 0.8404	 accuracy: 62.67
# Epoch [12/15] Step [368/368]	 Loss: 0.8615	 avg_Loss: 0.7909	 exec_time: 416 s	 train_time:	 1 h 27 m
# Epoch [12/15]	 avg_train Loss: 0.7909			 avg_validation Loss: 0.7777	 accuracy: 64.67
# Epoch [13/15] Step [368/368]	 Loss: 0.5444	 avg_Loss: 0.7638	 exec_time: 416 s	 train_time:	 1 h 35 m
# Epoch [13/15]	 avg_train Loss: 0.7638			 avg_validation Loss: 0.7474	 accuracy: 70.67
# Epoch [14/15] Step [368/368]	 Loss: 0.9828	 avg_Loss: 0.7856	 exec_time: 414 s	 train_time:	 1 h 42 m
# Epoch [14/15]	 avg_train Loss: 0.7856			 avg_validation Loss: 0.8281	 accuracy: 64.00
# Epoch [15/15] Step [368/368]	 Loss: 0.5953	 avg_Loss: 0.7722	 exec_time: 415 s	 train_time:	 1 h 50 m
# Epoch [15/15]	 avg_train Loss: 0.7722			 avg_validation Loss: 0.8530	 accuracy: 62.67

# %%
# load the model that got the best validation accuracy
if torch.cuda.is_available():
    model_Resnet.load_state_dict(torch.load('models/model_Resnet.pt'))
else:
    model_Resnet.load_state_dict(torch.load('models/model_Resnet.pt', map_location=torch.device('cpu')))

# Test model
with torch.no_grad():
    test(loaders, model_Resnet, criterion, use_cuda)

get_scores(model_Resnet, (450,576))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=60.0), HTML(value='')))
# Test Loss: 0.837614
#
# Test Accuracy of melanoma:  36%     (42/117)
# Test Accuracy of nevus:  68%     (269/393)
# Test Accuracy of seborrheic_keratosis:  53%     (48/90)
#
# Test Accuracy (Overall):                                                60%     (359/600)
#
# getting predictions on all test images:
# HBox(children=(FloatProgress(value=0.0, max=600.0), HTML(value='')))
# writing score csv file
# Category 1 Score: 0.590
# Category 2 Score: 0.848
# Category 3 Score: 0.719

# %% [markdown]
# # Test ResNet50

# %%
model_Resnet50= models.resnet50(pretrained = True)

for param in model_Resnet50.parameters():
    param.requires_grad = True
    
from collections import OrderedDict
classifier = nn.Sequential(OrderedDict([
                          ('fc1', nn.Linear(2048, 1024)),
                          ('Elu', nn.ELU()),
                          ('Dropout',nn.Dropout(0.05)),
                          ('fc2', nn.Linear(1024, 3)),
                          ]))

model_Resnet50.fc = classifier

if use_cuda:
    model_Resnet50 = model_Resnet50.cuda()

print(summary(model_Resnet50.to(device), torch.zeros((1, 3, 224, 224)).to(device), show_input=False, show_hierarchical=False, print_summary=False))
# Out:
# ------------------------------------------------------------------------------
#            Layer (type)          Output Shape         Param #     Tr. Param #
# ==============================================================================
#                Conv2d-1     [1, 64, 112, 112]           9,408           9,408
#           BatchNorm2d-2     [1, 64, 112, 112]             128             128
#                  ReLU-3     [1, 64, 112, 112]               0               0
#             MaxPool2d-4       [1, 64, 56, 56]               0               0
#            Bottleneck-5      [1, 256, 56, 56]          75,008          75,008
#            Bottleneck-6      [1, 256, 56, 56]          70,400          70,400
#            Bottleneck-7      [1, 256, 56, 56]          70,400          70,400
#            Bottleneck-8      [1, 512, 28, 28]         379,392         379,392
#            Bottleneck-9      [1, 512, 28, 28]         280,064         280,064
#           Bottleneck-10      [1, 512, 28, 28]         280,064         280,064
#           Bottleneck-11      [1, 512, 28, 28]         280,064         280,064
#           Bottleneck-12     [1, 1024, 14, 14]       1,512,448       1,512,448
#           Bottleneck-13     [1, 1024, 14, 14]       1,117,184       1,117,184
#           Bottleneck-14     [1, 1024, 14, 14]       1,117,184       1,117,184
#           Bottleneck-15     [1, 1024, 14, 14]       1,117,184       1,117,184
#           Bottleneck-16     [1, 1024, 14, 14]       1,117,184       1,117,184
#           Bottleneck-17     [1, 1024, 14, 14]       1,117,184       1,117,184
#           Bottleneck-18       [1, 2048, 7, 7]       6,039,552       6,039,552
#           Bottleneck-19       [1, 2048, 7, 7]       4,462,592       4,462,592
#           Bottleneck-20       [1, 2048, 7, 7]       4,462,592       4,462,592
#    AdaptiveAvgPool2d-21       [1, 2048, 1, 1]               0               0
#               Linear-22             [1, 1024]       2,098,176       2,098,176
#                  ELU-23             [1, 1024]               0               0
#              Dropout-24             [1, 1024]               0               0
#               Linear-25                [1, 3]           3,075           3,075
# ==============================================================================
# Total params: 25,609,283
# Trainable params: 25,609,283
# Non-trainable params: 0
# ------------------------------------------------------------------------------

# %%
# Set up dataloaders
image_size = (224,224)  # max(450,576)
num_workers = 1
batch_size_train = 10
batch_size_val = 10
batch_size_test = 10
loaders=get_loaders(image_size, batch_size_train, batch_size_val, batch_size_test, num_workers)

# Define parameters
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model_Resnet50.parameters(), lr=0.0001)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=3)

# Train model
n_epochs = 15
print_every = 365
save_path = './models'
model_Resnet50, train_loss, val_loss = train(n_epochs, loaders, model_Resnet50, optimizer, criterion, use_cuda,
                                           'model_Resnet50.pt', is_inception=False)

# Display loss reduction profile
plot_loss('ResNet_50', train_loss, val_loss)
# Out:
# Epoch [1/15] Step [365/365]	 Loss: 0.9679	 avg_Loss: 0.7500	 exec_time: 410 s	 train_time:	 0 h 6 m
# Epoch [1/15]	 avg_train Loss: 0.7500			 avg_validation Loss: 0.8080	 val_accuracy: 70.00
# improved model saved to disk
# Epoch [2/15] Step [365/365]	 Loss: 0.3830	 avg_Loss: 0.6121	 exec_time: 438 s	 train_time:	 0 h 14 m
# Epoch [2/15]	 avg_train Loss: 0.6121			 avg_validation Loss: 0.6576	 val_accuracy: 69.33
# improved model saved to disk
# Epoch [3/15] Step [365/365]	 Loss: 0.7509	 avg_Loss: 0.5697	 exec_time: 440 s	 train_time:	 0 h 22 m
# Epoch [3/15]	 avg_train Loss: 0.5697			 avg_validation Loss: 0.7308	 val_accuracy: 70.00
# Epoch [4/15] Step [365/365]	 Loss: 1.3105	 avg_Loss: 0.5304	 exec_time: 430 s	 train_time:	 0 h 30 m
# Epoch [4/15]	 avg_train Loss: 0.5304			 avg_validation Loss: 0.5619	 val_accuracy: 78.00
# improved model saved to disk
# Epoch [5/15] Step [365/365]	 Loss: 0.2630	 avg_Loss: 0.4818	 exec_time: 417 s	 train_time:	 0 h 37 m
# Epoch [5/15]	 avg_train Loss: 0.4818			 avg_validation Loss: 0.4975	 val_accuracy: 78.00
# improved model saved to disk
# Epoch [6/15] Step [365/365]	 Loss: 1.0411	 avg_Loss: 0.4851	 exec_time: 418 s	 train_time:	 0 h 45 m
# Epoch [6/15]	 avg_train Loss: 0.4851			 avg_validation Loss: 0.4969	 val_accuracy: 80.00
# improved model saved to disk
# Epoch [7/15] Step [365/365]	 Loss: 0.1332	 avg_Loss: 0.4320	 exec_time: 413 s	 train_time:	 0 h 52 m
# Epoch [7/15]	 avg_train Loss: 0.4320			 avg_validation Loss: 0.6923	 val_accuracy: 75.33
# Epoch [8/15] Step [365/365]	 Loss: 0.5462	 avg_Loss: 0.4270	 exec_time: 413 s	 train_time:	 0 h 59 m
# Epoch [8/15]	 avg_train Loss: 0.4270			 avg_validation Loss: 0.5504	 val_accuracy: 78.00
# Epoch [9/15] Step [365/365]	 Loss: 2.3621	 avg_Loss: 0.4009	 exec_time: 414 s	 train_time:	 1 h 7 m
# Epoch [9/15]	 avg_train Loss: 0.4009			 avg_validation Loss: 0.3511	 val_accuracy: 86.67
# improved model saved to disk
# Epoch [10/15] Step [365/365]	 Loss: 0.3598	 avg_Loss: 0.3639	 exec_time: 416 s	 train_time:	 1 h 14 m
# Epoch [10/15]	 avg_train Loss: 0.3639			 avg_validation Loss: 0.5017	 val_accuracy: 79.33
# Epoch [11/15] Step [365/365]	 Loss: 0.0615	 avg_Loss: 0.3493	 exec_time: 416 s	 train_time:	 1 h 22 m
# Epoch [11/15]	 avg_train Loss: 0.3493			 avg_validation Loss: 0.4482	 val_accuracy: 82.00
# Epoch [12/15] Step [365/365]	 Loss: 0.2575	 avg_Loss: 0.3336	 exec_time: 419 s	 train_time:	 1 h 29 m
# Epoch [12/15]	 avg_train Loss: 0.3336			 avg_validation Loss: 0.6369	 val_accuracy: 75.33
# Epoch [13/15] Step [365/365]	 Loss: 0.2670	 avg_Loss: 0.3323	 exec_time: 422 s	 train_time:	 1 h 37 m
# Epoch [13/15]	 avg_train Loss: 0.3323			 avg_validation Loss: 0.5446	 val_accuracy: 82.00
# Epoch [14/15] Step [365/365]	 Loss: 0.3104	 avg_Loss: 0.2582	 exec_time: 420 s	 train_time:	 1 h 44 m
# Epoch [14/15]	 avg_train Loss: 0.2582			 avg_validation Loss: 0.5036	 val_accuracy: 86.67
# Epoch [15/15] Step [365/365]	 Loss: 0.0294	 avg_Loss: 0.2194	 exec_time: 420 s	 train_time:	 1 h 52 m
# Epoch [15/15]	 avg_train Loss: 0.2194			 avg_validation Loss: 0.3960	 val_accuracy: 88.00

# %%
# load the model that got the best validation accuracy
if torch.cuda.is_available():
    model_Resnet50.load_state_dict(torch.load('models/model_Resnet50.pt'))
else:
    model_Resnet50.load_state_dict(torch.load('models/model_Resnet50.pt', map_location=torch.device('cpu')))

num_classes = 3

# Test model
with torch.no_grad():
    test(loaders, model_Resnet50, criterion, use_cuda)

    get_scores(model_Resnet50, (450,576))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=60.0), HTML(value='')))
# Test Loss: 0.684818
#
# Test Accuracy of melanoma:  65%     (76/117)
# Test Accuracy of nevus:  71%     (279/393)
# Test Accuracy of seborrheic_keratosis:  93%     (84/90)
#
# Test Accuracy (Overall):                                                73%     (439/600)
#
# getting predictions on all test images:
# HBox(children=(FloatProgress(value=0.0, max=600.0), HTML(value='')))
# writing score csv file
# Category 1 Score: 0.687
# Category 2 Score: 0.920
# Category 3 Score: 0.803

# %%
# Set up dataloaders
image_size = (224,224)  # max(450,576)
num_workers = 1
batch_size_train = 10
batch_size_val = 10
batch_size_test = 10
loaders=get_loaders(image_size, batch_size_train, batch_size_val, batch_size_test, num_workers)

# Define parameters
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model_Resnet50.parameters(), lr=0.00001)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=3)

# Train model
n_epochs = 10
print_every = 365
save_path = './models'
model_Resnet50, train_loss, val_loss = train(n_epochs, loaders, model_Resnet50, optimizer, criterion, use_cuda,
                                           'model_Resnet50_fine.pt', is_inception=False)

# Display loss reduction profile
plot_loss('ResNet_50', train_loss, val_loss)
# Out:
# Epoch [1/10] Step [365/365]	 Loss: 0.2687	 avg_Loss: 0.3075	 exec_time: 415 s	 train_time:	 0 h 6 m
# Epoch [1/10]	 avg_train Loss: 0.3075			 avg_validation Loss: 0.3323	 val_accuracy: 88.00
# improved model saved to disk
# Epoch [2/10] Step [108/365]	 Loss: 0.2764	 avg_Loss: 0.2649	 exec_time: 120 s	 train_time:	 0 h 9 m

# %% [markdown]
# # Try Ensemble approach for classification

# %%
def get_predictions_ensemble(model1, model2, model3, input_img_dim=(224,224)):
    
    batch_size_test = 1
    loaders = get_loaders (input_img_dim, batch_size_train, batch_size_val, batch_size_test, num_workers)
    
    model1.eval() # Model predicting Melanoma
    model2.eval() # Model predicting Nevus   - best predicting model
    model3.eval()  # Model predicting Seborreic
    
    # monitor test accuracy
    class_correct = list(0. for i in range(num_classes))
    class_total = list(0. for i in range(num_classes))
    correct = 0

    for data, label in tqdm(loaders['test']):
        
        if use_cuda:
            data = data.cuda()
        
        output1 = model1(data)
        output2 = model2(data)
        output3 = model3(data)
        
        # Select output probabilities for each class
        output1 = torch.nn.functional.softmax(output1, dim=1)
        prob1, pred1 = torch.max(output1, dim=1)
        if pred1 == 0:
            output1 = output1 * 2
            
        output2 = torch.nn.functional.softmax(output2, dim=1)
        prob2, pred2 = torch.max(output2, dim=1)
        if pred2 == 1:
            output2 = output2 * 4
        
        output3 = torch.nn.functional.softmax(output3, dim=1)
        prob3, pred3 = torch.max(output3, dim=1)
        if pred3 == 2:
            output3 = output3 * 2
        
        # convert ensemble probabilities to predicted class
        tot_prob = output1.squeeze()[0] + output2.squeeze()[1] + output3.squeeze()[2]
        prob_melanoma = output1.squeeze()[0] / tot_prob
        prob_nevus = output2.squeeze()[1] / tot_prob
        prob_sebo = output3.squeeze()[2] / tot_prob
        
        prob = np.array([prob_melanoma, prob_nevus, prob_sebo])
        
        prediction = np.argmax(prob)
        
        # calculate test accuracy for each object class
        class_correct[label] += (prediction==label.cpu().detach().numpy().squeeze()).item()
        class_total[label] += 1
        
    for i in range(num_classes):
        if class_total[i] > 0:
            
            print('Test Accuracy of {}:'.format(labels[i]),
              ' {:.0f}%'.format(100 * class_correct[i] / class_total[i]).ljust(8,' '), 
              '({:.0f}/{:.0f})'.format(np.sum(class_correct[i]), np.sum(class_total[i])))
            
        else:
            print('Test Accuracy of {}: N/A (no training examples)'.format(labels[i]))
                      
    print('\nTest Accuracy (Overall):\t {:.0f}%'.format(100. * np.sum(class_correct) / np.sum(class_total)).expandtabs(71),
      '\t({:.0f}/{:.0f})'.format(np.sum(class_correct), np.sum(class_total)).expandtabs(4))

# %%
num_classes = 3
## Specify model architecture

#Model1
model_Resnet50= models.resnet50(pretrained = True)
classifier = nn.Sequential(OrderedDict([
                          ('fc1', nn.Linear(2048, 1024)),
                          ('Elu', nn.ELU()),
                          ('Dropout',nn.Dropout(0.05)),
                          ('fc2', nn.Linear(1024, 3)),
                          ]))
model_Resnet50.fc = classifier

#Models 2 & 3
model_inception = models.inception_v3(pretrained=True, aux_logits=True)             # Be careful, InceptionV3 expects (299,299) sized images and has auxiliary output
model_inception = model_inception.to(device)

model_inception.AuxLogits.fc = nn.Linear(768, num_classes)
BasicConv2d = nn.Sequential(OrderedDict([('conv', nn.Conv2d(2048, 192, kernel_size=(1,1), stride=(1,1))),
                                         ('bn', nn.BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True))]))
classifier = nn.Sequential(OrderedDict([ ('fc1', nn.Linear(2048, 512)),     
                                         ('relu', nn.ReLU()),
                                        ('drop', nn.Dropout(0.4)),
                                         ('fc2', nn.Linear(512, num_classes)) 
                                         ]))                                                # ('output', nn.Softmax(dim=1))
model_inception.Mixed_7c.branch_pool = BasicConv2d
model_inception.fc = classifier


model1 = model_Resnet50
model2 = model_inception
model3 = model_inception

# load the model that got the best validation accuracy
if torch.cuda.is_available():
    model1 = model1.cuda()
    model2 = model2.cuda()
    model3 = model3.cuda()
    
    model1.load_state_dict(torch.load('models/model_Resnet50.pt'))
    model2.load_state_dict(torch.load('models/model_inception_6.pt'))
    model3.load_state_dict(torch.load('models/model_inception_2_fine.pt'))
    
else:
    model1.load_state_dict(torch.load('models/model_Resnet50.pt', map_location=torch.device('cpu')))
    model2.load_state_dict(torch.load('models/model_inception_6.pt', map_location=torch.device('cpu')))
    model3.load_state_dict(torch.load('models/model_inception_2_fine.pt', map_location=torch.device('cpu')))

# %%
get_predictions_ensemble(model1, model2, model3, input_img_dim=(224,224))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=600.0), HTML(value='')))
# Test Accuracy of melanoma:  41%     (48/117)
# Test Accuracy of nevus:  50%     (196/393)
# Test Accuracy of seborrheic_keratosis:  86%     (77/90)
#
# Test Accuracy (Overall):                                                54%     (321/600)
